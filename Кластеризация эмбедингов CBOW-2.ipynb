# %%
import Wishart
from Wishart import Wishart
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.metrics import calinski_harabasz_score
import pickle
from sklearn.cluster import KMeans

# %%
from s_dbw import SD
#https://github.com/intelligent-environments-lab/ProfileClustering/blob/master/Clustering%20Analysis/Clustering%20Validation%20Metrics.ipynb
# метрики взяты с этого сайта 
def divide(data, labels):
    clusters = set(labels)
    clusters_data = []
    for cluster in clusters:
        clusters_data.append(data[labels == cluster, :])
    return clusters_data

def get_centroids(clusters):
    centroids = []
    for cluster_data in clusters:
        centroids.append(cluster_data.mean(axis=0))
    return centroids

def SST(data):
    c = get_centroids([data])
    return ((data - c) ** 2).sum()

def SSE(clusters, centroids):
    result = 0
    for cluster, centroid in zip(clusters, centroids):
        result += ((cluster - centroid) ** 2).sum()
    return result

# Clear the store before running each time
within_cluster_dist_sum_store = {}
def within_cluster_dist_sum(cluster, centroid, cluster_id):
    if cluster_id in within_cluster_dist_sum_store:
        return within_cluster_dist_sum_store[cluster_id]
    else:
        result = (((cluster - centroid) ** 2).sum(axis=1)**.5).sum()
        within_cluster_dist_sum_store[cluster_id] = result
    return result

def RMSSTD(data, clusters, centroids):
    df = data.shape[0] - len(clusters)
    attribute_num = data.shape[1]
    return (SSE(clusters, centroids) / (attribute_num * df)) ** .5

# equal to separation / (cohesion + separation)
def RS(data, clusters, centroids):
    sst = SST(data)
    sse = SSE(clusters, centroids)
    return (sst - sse) / sst

def DB_find_max_j(clusters, centroids, i):
    max_val = 0
    max_j = 0
    for j in range(len(clusters)):
        if j == i:
            continue
        cluster_i_stat = within_cluster_dist_sum(clusters[i], centroids[i], i) / clusters[i].shape[0]
        cluster_j_stat = within_cluster_dist_sum(clusters[j], centroids[j], j) / clusters[j].shape[0]
        val = (cluster_i_stat + cluster_j_stat) / (((centroids[i] - centroids[j]) ** 2).sum() ** .5)
        if val > max_val:
            max_val = val
            max_j = j
    return max_val

def DB(data, clusters, centroids):
    result = 0
    for i in range(len(clusters)):
        result += DB_find_max_j(clusters, centroids, i)
    return result / len(clusters)

def XB(data, clusters, centroids):
    sse = SSE(clusters, centroids)
    min_dist = ((centroids[0] - centroids[1]) ** 2).sum()
    for centroid_i, centroid_j in list(product(centroids, centroids)):
        if (centroid_i - centroid_j).sum() == 0:
            continue
        dist = ((centroid_i - centroid_j) ** 2).sum()
        if dist < min_dist:
            min_dist = dist
    return sse / (data.shape[0] * min_dist)

def inter_cluster_distances(labels, distances, method='nearest'):
    """Calculates the distances between the two nearest points of each cluster.
    :param labels: a list containing cluster labels for each of the n elements
    :param distances: an n x n numpy.array containing the pairwise distances between elements
    :param method: `nearest` for the distances between the two nearest points in each cluster, or `farthest`
    """
    
    
    CLUSTER_DISTANCE_METHODS = ['nearest', 'farthest']
    
    if method not in CLUSTER_DISTANCE_METHODS:
        raise ValueError(
            'method must be one of {}'.format(CLUSTER_DISTANCE_METHODS))

    if method == 'nearest':
        return __cluster_distances_by_points(labels, distances)
    elif method == 'farthest':
        return __cluster_distances_by_points(labels, distances, farthest=True)


def __cluster_distances_by_points(labels, distances, farthest=False):
    n_unique_labels = len(np.unique(labels))
    cluster_distances = np.full((n_unique_labels, n_unique_labels),
                                float('inf') if not farthest else 0)

    np.fill_diagonal(cluster_distances, 0)

    for i in np.arange(0, len(labels) - 1):
        for ii in np.arange(i, len(labels)):
            if labels[i] != labels[ii] and (
                (not farthest and
                 distances[i, ii] < cluster_distances[labels[i], labels[ii]])
                    or
                (farthest and
                 distances[i, ii] > cluster_distances[labels[i], labels[ii]])):
                cluster_distances[labels[i], labels[ii]] = cluster_distances[
                    labels[ii], labels[i]] = distances[i, ii]
    return cluster_distances


def diameter(labels, distances, method='farthest'):
    """Calculates cluster diameters
    :param labels: a list containing cluster labels for each of the n elements
    :param distances: an n x n numpy.array containing the pairwise distances between elements
    :param method: either `mean_cluster` for the mean distance between all elements in each cluster, or `farthest` for the distance between the two points furthest from each other
    """
    DIAMETER_METHODS = ['mean_cluster', 'farthest']
    if method not in DIAMETER_METHODS:
        raise ValueError('method must be one of {}'.format(DIAMETER_METHODS))

    n_clusters = len(np.unique(labels))
    diameters = np.zeros(n_clusters)

    if method == 'mean_cluster':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii]:
                    diameters[labels[i]] += distances[i, ii]

        for i in range(len(diameters)):
            diameters[i] /= sum(labels == i)

    elif method == 'farthest':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii] and distances[i, ii] > diameters[
                        labels[i]]:
                    diameters[labels[i]] = distances[i, ii]
    return diameters


def dunn(data, labels, diameter_method='farthest',
         cdist_method='nearest'):
    distances = euclidean_distances(data)
    """
    Dunn index for cluster validation (larger is better).
    
    .. math:: D = \\min_{i = 1 \\ldots n_c; j = i + 1\ldots n_c} \\left\\lbrace \\frac{d \\left( c_i,c_j \\right)}{\\max_{k = 1 \\ldots n_c} \\left(diam \\left(c_k \\right) \\right)} \\right\\rbrace
    
    where :math:`d(c_i,c_j)` represents the distance between
    clusters :math:`c_i` and :math:`c_j`, and :math:`diam(c_k)` is the diameter of cluster :math:`c_k`.
    Inter-cluster distance can be defined in many ways, such as the distance between cluster centroids or between their closest elements. Cluster diameter can be defined as the mean distance between all elements in the cluster, between all elements to the cluster centroid, or as the distance between the two furthest elements.
    The higher the value of the resulting Dunn index, the better the clustering
    result is considered, since higher values indicate that clusters are
    compact (small :math:`diam(c_k)`) and far apart (large :math:`d \\left( c_i,c_j \\right)`).
    :param labels: a list containing cluster labels for each of the n elements
    :param distances: an n x n numpy.array containing the pairwise distances between elements
    :param diameter_method: see :py:function:`diameter` `method` parameter
    :param cdist_method: see :py:function:`diameter` `method` parameter
    
    .. [Kovacs2005] Kovács, F., Legány, C., & Babos, A. (2005). Cluster validity measurement techniques. 6th International Symposium of Hungarian Researchers on Computational Intelligence.
    """

    labels = LabelEncoder().fit(labels).transform(labels)

    ic_distances = inter_cluster_distances(labels, distances, cdist_method)
    min_distance = min(ic_distances[ic_distances.nonzero()])
    max_diameter = max(diameter(labels, distances, diameter_method))

    return min_distance / max_diameter

def mod_hubert_statistic(data, clusters, centroids):
    index = 0 
    for i in range(len(clusters)):
        for j in range(len(clusters)):
            if i == j:
                continue
            
            d_c = np.linalg.norm(np.array(centroids[i]) - np.array(centroids[j]))
            for x in clusters[i]:
                for y in clusters[j]:
                    index += np.linalg.norm(np.array(x) - np.array(y)) * d_c
    return index * 2 /(len(data) * (len(data) - 1))

def i_index(data, clusters, centroids):
    c = data.mean(axis=0)
    sum_d_c = np.sum(np.linalg.norm(data - c, axis=1))
    m = 0
    for i in range(len(centroids)):
        for j in range(i + 1, len(centroids)):
            m = max(m, np.linalg.norm(centroids[i] - centroids[j]))
    s = 0
    for i in range(len(clusters)):
        s += np.sum(np.linalg.norm(clusters[i] - centroids[i], axis=1))
    return (sum_d_c * m / (len(clusters) * s))**len(data[0])

def Sep(labels, k, dk, dist):
    clusters = sorted(set(labels))
    max_sep = None
    for cluster in clusters:
        cluster_data = dist[labels == cluster]
        cluster_data = cluster_data[:, labels != cluster]
        cluster_dk = dk[labels == cluster]
        sep = len(cluster_data[cluster_data <= np.c_[cluster_dk]]) / (k * cluster_data.shape[0])
        if max_sep is None or max_sep < sep:
            max_sep = sep
    return max_sep

def Com(labels, dist):
    clusters = sorted(set(labels))
    com = 0
    max_com = 0
    for cluster in clusters:
        cluster_data = dist[labels == cluster]
        cluster_data = cluster_data[:, labels == cluster]
        n_i = cluster_data.shape[0]
#        print(n_i, cluster_data.sum())
        if n_i > 1:
            cur_sum = 2 * cluster_data.sum() / (n_i * (n_i - 1))
            com += cur_sum
            if max_com < cur_sum:
                max_com = cur_sum
    return com, max_com

def CVNN(labels, k, dk, dist):
    com, max_com = Com(labels, dist)
    return Sep(labels, k, dk, dist) + com / max_com 

def get_validation_scores(data, labels, k, dk, dist):
    within_cluster_dist_sum_store.clear()
    
    clusters = divide(data, labels)
    centroids = get_centroids(clusters)
    
    scores = {}
#     scores['1 RMSSTD'] = RMSSTD(data, clusters, centroids)
    scores['RS'] = RS(data, clusters, centroids)
#     scores['3 H'] = mod_hubert_statistic(data, clusters, centroids)
#     scores['CH'] = calinski_harabasz_score(data, labels)
#     scores['5 I'] = i_index(data, clusters, centroids)
#     scores['6 D'] = dunn(data, labels)
#     scores['7 S'] = silhouette_score(data, labels)
#     scores['8 DB'] = DB(data, clusters, centroids)
    scores['XB'] = XB(data, clusters, centroids)
    scores['SD'] = SD(data, labels)
#     scores['11 S_Dbw'] = S_Dbw(data, labels)
#     scores['12 CVNN'] = CVNN(labels, k, dk, dist)
    return scores

# %%
# Скачиваем словарь слов - эмбедингов skip-gram
dictionary_CBOW = pickle.load(open("dictionary_W2V_CBOW.pkl", 'rb'))

# %%
len(dictionary_CBOW)
# Out:
# 42243

# %%
# Достаем эмбеднги
dict_val = dictionary_CBOW.values()
dict_val = np.array(list(dict_val))

# %%
# Возьмем подвыборку для обучения
small_CBOW = np.array(pd.DataFrame(dict_val).head(10000))

# %%
words_CBOW = dictionary_CBOW.keys()
words_CBOW = np.array(list(words_CBOW))
small_words_CBOW = np.array(pd.DataFrame(words_CBOW).head(10000))

# %%
small_CBOW
# Out:
# array([[ 0.75793564, -1.3694273 , -1.8972765 , ..., -1.0800457 ,
#          0.5216813 ,  0.859525  ],
#        [ 1.3016802 ,  0.9904103 , -2.8725188 , ..., -0.187297  ,
#          0.00884704, -0.9116756 ],
#        [-0.66935915, -0.30105323, -0.6148432 , ..., -1.6956683 ,
#         -0.59774643,  0.37526286],
#        ...,
#        [ 0.18065442,  0.29248595,  0.074173  , ...,  0.14599663,
#         -0.12540849, -0.10024214],
#        [-0.13846715, -0.34843364, -0.04960111, ..., -0.3262695 ,
#          0.11980201, -0.05938642],
#        [-0.02323388, -0.05329185, -0.00744321, ...,  0.19467005,
#         -0.30184802,  0.19303866]], dtype=float32)

# %%
# Запустим алгоритм кластеризации Wishart на этой подвыборке
datasets_clustering1 = []
datasets_names1 = []
num_clusters = 5
k = 2
while num_clusters >= 5:
    WC = Wishart(k, 0.001)
    res = WC.fit(small_CBOW)
    num_clusters = np.max(res)
    print(num_clusters)
    datasets_clustering1.append((small_CBOW, WC))
    datasets_names1 += ['k = ' + str(k)]
    k += 1
# Out:
# Start clustering
# 38
# Start clustering
# 15
# Start clustering
# 10
# Start clustering
# 5
# Start clustering
# 4

# %%
from itertools import combinations, product
scores_list1 = []
dict_list1 = [] # список словарей 
for (data, WC), data_name in zip(datasets_clustering1, datasets_names1):
#     print(data_name)
    if(len(set(WC.object_labels)) == 1):
        print('Set with one cluster')
        continue
#     print(len(set(WC.object_labels)))
    scores = get_validation_scores(data, WC.object_labels, k=10, dk=WC.dk_, dist=WC.dist_)
    scores_list1 += [scores]
#     for key in scores: 
#         print('\t' + key + ': %.4f' % scores[key])
    dict_ = {}
    for i in set(WC.object_labels):
        dict_[i] =  small_words_CBOW[WC.object_labels==i]
    dict_list1 += [dict_]

# %%
datasets_names1
# Out:
# ['k = 2', 'k = 3', 'k = 4', 'k = 5', 'k = 6']

# %%
from collections import defaultdict
metrics_k_grid = defaultdict(list)
k_grid = np.arange(2, 7, 1)
for i in range(len(scores_list1)):
    scores = scores_list1[i]
    for key in scores:
        metrics_k_grid[key].append(scores[key])

# %%
fig, axs = plt.subplots(3, figsize=(4,12))
for i in range(3):
    if i == 0: axs[i].set_title('CBOW clustering metrics')
    metricname = list(metrics_k_grid.keys())[i]
    y = metrics_k_grid[metricname]
    axs[i].set_ylabel(metricname)
    axs[i].set_xlabel('k')
    axs[i].plot(k_grid[:len(y)], y)

# %%
# Запустим алгоритм кластеризации Wishart на этой подвыборке
datasets_clustering = []
datasets_names = []
num_clusters = 2
k = 2
while num_clusters >= 2:
    WC = Wishart(k, 0.001)
    res = WC.fit(small_CBOW)
    num_clusters = np.max(res)
    print(num_clusters)
    datasets_clustering.append((small_CBOW, WC))
    datasets_names += ['k = ' + str(k)]
    k += 2
# Out:
# Start clustering
# 46
# Start clustering
# 10
# Start clustering
# 4
# Start clustering
# 3
# Start clustering
# 3
# Start clustering
# 3
# Start clustering
# 2
# Start clustering
# 1

# %%
from itertools import combinations, product
scores_list = []
dict_list = [] # список словарей 
for (data, WC), data_name in zip(datasets_clustering, datasets_names):
#     print(data_name)
    if(len(set(WC.object_labels)) == 1):
        print('Set with one cluster')
        continue
#     print(len(set(WC.object_labels)))
    scores = get_validation_scores(data, WC.object_labels, k=10, dk=WC.dk_, dist=WC.dist_)
    scores_list += [scores]
#     for key in scores: 
#         print('\t' + key + ': %.4f' % scores[key])
    dict_ = {}
    for i in set(WC.object_labels):
        dict_[i] =  small_words_CBOW[WC.object_labels==i]
    dict_list += [dict_]
# Out:
# Set with one cluster

# %%
print(dict_list)
# Out:
# [{0: array([['0'],
#        ['в'],
#        ['и'],
#        ...,
#        ['автоцентр'],
#        ['экг'],
#        ['э-0/0-0']], dtype=object), 1: array([['хундай'],
#        ['corolla'],
#        ['хендай'],
#        ['субару'],
#        ['cr-v'],
#        ['skoda'],
#        ['королл'],
#        ['камри'],
#        ['сузука'],
#        ['нексия'],
#        ['нисан'],
#        ['пассат'],
#        ['ровер'],
#        ['се'],
#        ['нива'],
#        ['еу'],
#        ['логан'],
#        ['корс'],
#        ['лиаз'],
#        ['peugeot'],
#        ['ман'],
#        ['accent'],
#        ['getz'],
#        ['rover'],
#        ['matiz'],
#        ['nexia'],
#        ['рав'],
#        ['octavia'],
#        ['астра'],
#        ['camry'],
#        ['lexus'],
#        ['борозда'],
#        ['ер'],
#        ['niva'],
#        ['astra'],
#        ['уборщица'],
#        ['x-trail'],
#        ['suzuki'],
#        ['гольф'],
#        ['акцент'],
#        ['at'],
#        ['иж'],
#        ['митцубиси'],
#        ['fusion'],
#        ['avensis'],
#        ['subaru'],
#        ['outlander'],
#        ['lacetti'],
#        ['метиз'],
#        ['teana'],
#        ['freightliner'],
#        ['комфорт'],
#        ['альмер'],
#        ['маляр']], dtype=object), 2: array([['area'],
#        ['ed'],
#        ['type'],
#        ['na'],
#        ['zz'],
#        ['dc'],
#        ['fb'],
#        ['заморозка'],
#        ['вымерзание'],
#        ['ee'],
#        ['lzz'],
#        ['дуб']], dtype=object), 3: array([['матрос'],
#        ['сержант'],
#        ['солдат'],
#        ['старшина']], dtype=object), 4: array([['арлингтон'],
#        ['murrey'],
#        ['лорд'],
#        ['кресло']], dtype=object), 5: array([['менделеев'],
#        ['ангарский'],
#        ['лев'],
#        ['декабрист'],
#        ['щербаков'],
#        ['реж'],
#        ['панфилов'],
#        ['вятский'],
#        ['адмирал'],
#        ['артем']], dtype=object), 6: array([['однокомнатный'],
#        ['комнатный'],
#        ['0-аба'],
#        ['0-ава'],
#        ['панельный'],
#        ['ез'],
#        ['бб'],
#        ['а-а']], dtype=object), 7: array([['samara'],
#        ['rostov'],
#        ['юр'],
#        ['р-0/0'],
#        ['задонский'],
#        ['krasnoyarsk']], dtype=object), 10: array([['арамит'],
#        ['evergreen'],
#        ['плафа']], dtype=object), 12: array([['октябрь-декабрь'],
#        ['октябрь-ноябрь'],
#        ['январь-апрель'],
#        ['март-апрель'],
#        ['июль-август'],
#        ['лето'],
#        ['сентябрь-октябрь'],
#        ['август-сентябрь'],
#        ['июнь-июль'],
#        ['февраль-март'],
#        ['апрель-май'],
#        ['май-июнь'],
#        ['январь-май'],
#        ['0–0'],
#        ['сентябрь-ноябрь'],
#        ['январь-декабрь'],
#        ['сентябрь-декабрь']], dtype=object), 14: array([['крош'],
#        ['шарм']], dtype=object), 15: array([['кронштейн'],
#        ['задок'],
#        ['арка'],
#        ['плинтус']], dtype=object), 16: array([['коричневый'],
#        ['полоска'],
#        ['акриловый']], dtype=object), 18: array([['глазной'],
#        ['сироп'],
#        ['инъекция'],
#        ['дозировать']], dtype=object), 19: array([['медпункт'],
#        ['прачечная'],
#        ['универмаг']], dtype=object), 20: array([['неэтичный'],
#        ['нечестный'],
#        ['поступок']], dtype=object), 21: array([['азот'],
#        ['диоксид'],
#        ['углерод']], dtype=object), 22: array([['люкс'],
#        ['маковый'],
#        ['начинка'],
#        ['рулет']], dtype=object), 26: array([['подстанция'],
#        ['трансформаторный'],
#        ['электропередача'],
#        ['пс'],
#        ['тп'],
#        ['ква'],
#        ['тп-0'],
#        ['вл-0'],
#        ['кл'],
#        ['ктп'],
#        ['кл-0'],
#        ['фидер'],
#        ['яч'],
#        ['ру-0'],
#        ['вл-0,0'],
#        ['ру-0,0']], dtype=object), 27: array([['швейный'],
#        ['пирожное'],
#        ['макаронный'],
#        ['трикотажный'],
#        ['мучной']], dtype=object), 28: array([['сын'],
#        ['мать'],
#        ['дочь'],
#        ['жена'],
#        ['муж'],
#        ['отец']], dtype=object), 33: array([['седьмой'],
#        ['восьмой'],
#        ['одиннадцатый'],
#        ['двенадцатый'],
#        ['четырнадцатый'],
#        ['тринадцатый'],
#        ['шестнадцатый']], dtype=object), 34: array([['сорный'],
#        ['древесно-кустарниковый'],
#        ['зарастание']], dtype=object), 35: array([['волга'],
#        ['каспий']], dtype=object), 36: array([['приемки-сдачи'],
#        ['сдача-прием'],
#        ['приема-сдача']], dtype=object), 37: array([['товароведческий'],
#        ['автотехнический'],
#        ['автотовароведческий'],
#        ['судебно-технический'],
#        ['судебно-бухгалтерский']], dtype=object), 39: array([['xviii'],
#        ['xix'],
#        ['xii'],
#        ['xvii']], dtype=object), 40: array([['вкх'],
#        ['жилищно-эксплуатационный'],
#        ['xxii'],
#        ['лицензированный']], dtype=object), 41: array([['примерно'],
#        ['юго-восток'],
#        ['юго-запад'],
#        ['север'],
#        ['северо-запад'],
#        ['запад'],
#        ['восток'],
#        ['северо-восток'],
#        ['юг']], dtype=object), 44: array([['рсфср'],
#        ['коллективно-долевой'],
#        ['ссср'],
#        ['общедолевой']], dtype=object), 45: array([['ида'],
#        ['фкрс'],
#        ['фкд-0/0']], dtype=object), 47: array([['сличительный'],
#        ['сверочный'],
#        ['сальдовый']], dtype=object), 52: array([['экономика'],
#        ['коньяк'],
#        ['звездочка'],
#        ['пятилетний'],
#        ['шампанское'],
#        ['автостраховщик']], dtype=object), 53: array([['оттиском'],
#        ['заверять'],
#        ['оттиска'],
#        ['гербовый']], dtype=object), 54: array([['торгово-закупочный'],
#        ['сыскной'],
#        ['лицензируемой'],
#        ['воспитательный']], dtype=object), 55: array([['пени-'],
#        ['составляет-'],
#        ['долга-']], dtype=object), 59: array([['ролик'],
#        ['плакат'],
#        ['листовка']], dtype=object), 62: array([['лейтенант'],
#        ['госинспектор'],
#        ['оперуполномоченный'],
#        ['майор']], dtype=object), 63: array([['выставочный'],
#        ['мирный'],
#        ['подъездной'],
#        ['крановый'],
#        ['подкрановый']], dtype=object), 64: array([['соревнование'],
#        ['концерт'],
#        ['фестиваль']], dtype=object), 74: array([['ээ'],
#        ['эь'],
#        ['эч'],
#        ['эы'],
#        ['эш'],
#        ['эя']], dtype=object), 75: array([['0.0.0'],
#        ['март'],
#        ['декабрь'],
#        ['январь'],
#        ['апрель'],
#        ['октябрь'],
#        ['июль'],
#        ['ноябрь'],
#        ['май'],
#        ['февраль'],
#        ['июнь'],
#        ['август'],
#        ['сентябрь']], dtype=object), 84: array([['литер'],
#        ['лит'],
#        ['литера']], dtype=object), 90: array([['следовать'],
#        ['усматриваться'],
#        ['видно']], dtype=object), 95: array([['аукцион'],
#        ['торг'],
#        ['конкурс']], dtype=object), 98: array([['отклоняться'],
#        ['отклонить'],
#        ['отклонять']], dtype=object), 103: array([['статья'],
#        ['ст'],
#        ['стать']], dtype=object)}, {0: array([['0'],
#        ['в'],
#        ['и'],
#        ...,
#        ['автоцентр'],
#        ['экг'],
#        ['э-0/0-0']], dtype=object), 1: array([['хундай'],
#        ['corolla'],
#        ['хендай'],
#        ['cr-v'],
#        ['ed'],
#        ['королл'],
#        ['type'],
#        ['камри'],
#        ['сузука'],
#        ['нексия'],
#        ['нисан'],
#        ['пассат'],
#        ['ровер'],
#        ['се'],
#        ['нива'],
#        ['логан'],
#        ['корс'],
#        ['peugeot'],
#        ['ман'],
#        ['accent'],
#        ['getz'],
#        ['rover'],
#        ['matiz'],
#        ['nexia'],
#        ['octavia'],
#        ['астра'],
#        ['camry'],
#        ['ер'],
#        ['rostov'],
#        ['niva'],
#        ['astra'],
#        ['x-trail'],
#        ['suzuki'],
#        ['гольф'],
#        ['акцент'],
#        ['иж'],
#        ['митцубиси'],
#        ['fusion'],
#        ['avensis'],
#        ['subaru'],
#        ['задонский'],
#        ['outlander'],
#        ['lacetti'],
#        ['teana'],
#        ['freightliner'],
#        ['альмер']], dtype=object), 2: array([['менделеев'],
#        ['ангарский'],
#        ['лев'],
#        ['декабрист'],
#        ['щербаков'],
#        ['реж'],
#        ['панфилов'],
#        ['вятский'],
#        ['артем']], dtype=object), 4: array([['0-ава'],
#        ['бб']], dtype=object), 5: array([['октябрь-декабрь'],
#        ['-0'],
#        ['октябрь-ноябрь'],
#        ['январь-апрель'],
#        ['март-апрель'],
#        ['июль-август'],
#        ['лето'],
#        ['сентябрь-октябрь'],
#        ['август-сентябрь'],
#        ['июнь-июль'],
#        ['февраль-март'],
#        ['апрель-май'],
#        ['май-июнь'],
#        ['январь-май'],
#        ['0–0'],
#        ['сентябрь-ноябрь'],
#        ['январь-декабрь'],
#        ['сентябрь-декабрь']], dtype=object), 6: array([['плафа'],
#        ['лорд']], dtype=object), 7: array([['сироп'],
#        ['дозировать']], dtype=object), 9: array([['ктп'],
#        ['фидер'],
#        ['яч'],
#        ['ру-0'],
#        ['вл-0,0'],
#        ['ру-0,0']], dtype=object), 10: array([['товароведческий'],
#        ['автотехнический'],
#        ['автотовароведческий'],
#        ['судебно-технический'],
#        ['судебно-бухгалтерский']], dtype=object), 11: array([['юго-восток'],
#        ['юго-запад'],
#        ['север'],
#        ['северо-запад'],
#        ['запад'],
#        ['восток'],
#        ['северо-восток'],
#        ['юг']], dtype=object), 13: array([['0.0.0'],
#        ['март'],
#        ['декабрь'],
#        ['январь'],
#        ['апрель'],
#        ['октябрь'],
#        ['июль'],
#        ['ноябрь'],
#        ['май'],
#        ['февраль'],
#        ['июнь'],
#        ['август'],
#        ['сентябрь']], dtype=object)}, {0: array([['0'],
#        ['в'],
#        ['и'],
#        ...,
#        ['автоцентр'],
#        ['экг'],
#        ['э-0/0-0']], dtype=object), 1: array([['хундай'],
#        ['хендай'],
#        ['cr-v'],
#        ['королл'],
#        ['камри'],
#        ['сузука'],
#        ['нексия'],
#        ['нисан'],
#        ['пассат'],
#        ['ровер'],
#        ['нива'],
#        ['логан'],
#        ['корс'],
#        ['peugeot'],
#        ['ман'],
#        ['accent'],
#        ['getz'],
#        ['rover'],
#        ['matiz'],
#        ['nexia'],
#        ['octavia'],
#        ['астра'],
#        ['camry'],
#        ['ер'],
#        ['niva'],
#        ['astra'],
#        ['x-trail'],
#        ['suzuki'],
#        ['гольф'],
#        ['акцент'],
#        ['иж'],
#        ['митцубиси'],
#        ['fusion'],
#        ['avensis'],
#        ['subaru'],
#        ['outlander'],
#        ['lacetti'],
#        ['teana'],
#        ['freightliner'],
#        ['альмер']], dtype=object), 2: array([['ангарский'],
#        ['вятский']], dtype=object), 3: array([['-0'],
#        ['октябрь-ноябрь'],
#        ['январь-апрель'],
#        ['март-апрель'],
#        ['июль-август'],
#        ['лето'],
#        ['сентябрь-октябрь'],
#        ['август-сентябрь'],
#        ['июнь-июль'],
#        ['февраль-март'],
#        ['апрель-май'],
#        ['май-июнь'],
#        ['январь-май'],
#        ['0–0'],
#        ['сентябрь-ноябрь'],
#        ['январь-декабрь'],
#        ['сентябрь-декабрь']], dtype=object), 5: array([['юго-восток'],
#        ['юго-запад'],
#        ['север'],
#        ['северо-запад'],
#        ['запад'],
#        ['восток'],
#        ['северо-восток']], dtype=object)}, {0: array([['0'],
#        ['в'],
#        ['и'],
#        ...,
#        ['автоцентр'],
#        ['экг'],
#        ['э-0/0-0']], dtype=object), 1: array([['хундай'],
#        ['хендай'],
#        ['cr-v'],
#        ['королл'],
#        ['камри'],
#        ['сузука'],
#        ['нексия'],
#        ['нисан'],
#        ['пассат'],
#        ['ровер'],
#        ['нива'],
#        ['логан'],
#        ['корс'],
#        ['peugeot'],
#        ['ман'],
#        ['accent'],
#        ['getz'],
#        ['rover'],
#        ['matiz'],
#        ['nexia'],
#        ['octavia'],
#        ['астра'],
#        ['camry'],
#        ['ер'],
#        ['niva'],
#        ['astra'],
#        ['x-trail'],
#        ['suzuki'],
#        ['гольф'],
#        ['акцент'],
#        ['иж'],
#        ['митцубиси'],
#        ['fusion'],
#        ['avensis'],
#        ['subaru'],
#        ['outlander'],
#        ['lacetti'],
#        ['teana'],
#        ['freightliner'],
#        ['альмер']], dtype=object), 2: array([['ангарский'],
#        ['вятский']], dtype=object), 3: array([['октябрь-ноябрь'],
#        ['март-апрель'],
#        ['сентябрь-октябрь'],
#        ['август-сентябрь'],
#        ['июнь-июль'],
#        ['февраль-март'],
#        ['апрель-май'],
#        ['май-июнь'],
#        ['январь-май'],
#        ['сентябрь-ноябрь'],
#        ['январь-декабрь'],
#        ['сентябрь-декабрь']], dtype=object)}, {0: array([['0'],
#        ['в'],
#        ['и'],
#        ...,
#        ['автоцентр'],
#        ['экг'],
#        ['э-0/0-0']], dtype=object), 1: array([['хундай'],
#        ['хендай'],
#        ['cr-v'],
#        ['королл'],
#        ['камри'],
#        ['сузука'],
#        ['нексия'],
#        ['нисан'],
#        ['пассат'],
#        ['ровер'],
#        ['нива'],
#        ['логан'],
#        ['корс'],
#        ['peugeot'],
#        ['ман'],
#        ['accent'],
#        ['getz'],
#        ['rover'],
#        ['matiz'],
#        ['nexia'],
#        ['астра'],
#        ['camry'],
#        ['ер'],
#        ['niva'],
#        ['astra'],
#        ['x-trail'],
#        ['suzuki'],
#        ['гольф'],
#        ['акцент'],
#        ['иж'],
#        ['митцубиси'],
#        ['fusion'],
#        ['avensis'],
#        ['subaru'],
#        ['outlander'],
#        ['lacetti'],
#        ['teana'],
#        ['freightliner'],
#        ['альмер']], dtype=object), 2: array([['ангарский'],
#        ['вятский']], dtype=object), 3: array([['март-апрель'],
#        ['июль-август'],
#        ['сентябрь-октябрь'],
#        ['август-сентябрь'],
#        ['июнь-июль'],
#        ['февраль-март'],
#        ['апрель-май'],
#        ['май-июнь'],
#        ['январь-май'],
#        ['сентябрь-ноябрь'],
#        ['январь-декабрь'],
#        ['сентябрь-декабрь']], dtype=object)}, {0: array([['0'],
#        ['в'],
#        ['и'],
#        ...,
#        ['автоцентр'],
#        ['экг'],
#        ['э-0/0-0']], dtype=object), 1: array([['хундай'],
#        ['хендай'],
#        ['cr-v'],
#        ['королл'],
#        ['камри'],
#        ['сузука'],
#        ['нексия'],
#        ['нисан'],
#        ['пассат'],
#        ['ровер'],
#        ['нива'],
#        ['логан'],
#        ['корс'],
#        ['peugeot'],
#        ['ман'],
#        ['accent'],
#        ['getz'],
#        ['rover'],
#        ['matiz'],
#        ['nexia'],
#        ['octavia'],
#        ['астра'],
#        ['camry'],
#        ['ер'],
#        ['niva'],
#        ['astra'],
#        ['x-trail'],
#        ['suzuki'],
#        ['гольф'],
#        ['акцент'],
#        ['иж'],
#        ['митцубиси'],
#        ['fusion'],
#        ['avensis'],
#        ['subaru'],
#        ['задонский'],
#        ['outlander'],
#        ['lacetti'],
#        ['teana'],
#        ['freightliner'],
#        ['альмер']], dtype=object), 2: array([['реж'],
#        ['вятский']], dtype=object), 3: array([['март-апрель'],
#        ['июль-август'],
#        ['сентябрь-октябрь'],
#        ['август-сентябрь'],
#        ['июнь-июль'],
#        ['февраль-март'],
#        ['апрель-май'],
#        ['май-июнь'],
#        ['январь-май'],
#        ['январь-декабрь'],
#        ['сентябрь-декабрь']], dtype=object)}, {0: array([['0'],
#        ['в'],
#        ['и'],
#        ...,
#        ['штепсельный'],
#        ['добавочный'],
#        ['экг']], dtype=object), 1: array([['пежо'],
#        ['нм'],
#        ['ет'],
#        ['хонда'],
#        ['хс'],
#        ['ке'],
#        ['он'],
#        ['ен'],
#        ['ое'],
#        ['хт'],
#        ['лада'],
#        ['ех'],
#        ['дэу'],
#        ['уа'],
#        ['ре'],
#        ['ум'],
#        ['ну'],
#        ['рх'],
#        ['ом'],
#        ['ух'],
#        ['фрунзе'],
#        ['фокус'],
#        ['уо'],
#        ['нх'],
#        ['ува'],
#        ['уна'],
#        ['ру'],
#        ['хм'],
#        ['хв'],
#        ['хо'],
#        ['хендэ'],
#        ['уу'],
#        ['ох'],
#        ['уе'],
#        ['cruiser'],
#        ['лансер'],
#        ['орджоникидзе'],
#        ['ск'],
#        ['daewoo'],
#        ['volkswagen'],
#        ['area'],
#        ['революция'],
#        ['некрасов'],
#        ['юра'],
#        ['шкода'],
#        ['honda'],
#        ['со'],
#        ['степной'],
#        ['сие'],
#        ['хр'],
#        ['ху'],
#        ['ленд'],
#        ['лексус'],
#        ['мх'],
#        ['урицкий'],
#        ['володарский'],
#        ['хе'],
#        ['оп'],
#        ['lancer'],
#        ['интернациональный'],
#        ['хн'],
#        ['марта'],
#        ['scania'],
#        ['хундай'],
#        ['королева'],
#        ['кор'],
#        ['академик'],
#        ['opel'],
#        ['тракт'],
#        ['юла'],
#        ['чернышевский'],
#        ['камаз-0'],
#        ['сказка'],
#        ['focus'],
#        ['тамбовский'],
#        ['ленинский'],
#        ['истый'],
#        ['о-0'],
#        ['дл'],
#        ['ил'],
#        ['овощехранилище'],
#        ['rav'],
#        ['уаз-0'],
#        ['телятник'],
#        ['балтийский'],
#        ['революционный'],
#        ['сканий'],
#        ['corolla'],
#        ['030'],
#        ['зд'],
#        ['схпк'],
#        ['lada'],
#        ['невский'],
#        ['металлург'],
#        ['аз'],
#        ['крузер'],
#        ['хендай'],
#        ['пирогов'],
#        ['бенц'],
#        ['субару'],
#        ['й'],
#        ['пд'],
#        ['тюмень'],
#        ['г-0'],
#        ['cr-v'],
#        ['мкд'],
#        ['мбдоу'],
#        ['skoda'],
#        ['аккумулятор'],
#        ['теруправление'],
#        ['ильич'],
#        ['счетами-фактурами'],
#        ['герцен'],
#        ['пермский'],
#        ['ed'],
#        ['умп'],
#        ['цвиллинг'],
#        ['аэродромный'],
#        ['кировский'],
#        ['административно-производственный'],
#        ['пу'],
#        ['сл'],
#        ['королл'],
#        ['дд'],
#        ['вентилятор'],
#        ['type'],
#        ['ком'],
#        ['ga'],
#        ['камри'],
#        ['маз-0'],
#        ['веб-адрес'],
#        ['общ'],
#        ['грунтовка'],
#        ['антресоль'],
#        ['являть'],
#        ['кто'],
#        ['тележка'],
#        ['ленточный'],
#        ['волгоградский'],
#        ['уд'],
#        ['тургенев'],
#        ['зил-0'],
#        ['фиат'],
#        ['закрываться'],
#        ['крупский'],
#        ['пт'],
#        ['сузука'],
#        ['рус'],
#        ['рз'],
#        ['0,0,0'],
#        ['арамит'],
#        ['э-0'],
#        ['дс'],
#        ['есть'],
#        ['библиотека'],
#        ['0.0.0.0'],
#        ['samara'],
#        ['пробивка'],
#        ['казани'],
#        ['поквартальный'],
#        ['глубокий'],
#        ['расплодить'],
#        ['дст'],
#        ['птицефабрика'],
#        ['потолочный'],
#        ['нексия'],
#        ['маяковский'],
#        ['владимир'],
#        ['краз'],
#        ['девятиэтажный'],
#        ['na'],
#        ['saratov'],
#        ['зн'],
#        ['нисан'],
#        ['нахимов'],
#        ['автогараж'],
#        ['самарский'],
#        ['посредство'],
#        ['бс'],
#        ['встроенно-пристроенный'],
#        ['сто'],
#        ['отлив'],
#        ['пассат'],
#        ['рефрижератор'],
#        ['четырехэтажный'],
#        ['наружное'],
#        ['ярославский'],
#        ['ровер'],
#        ['фсс'],
#        ['карниз'],
#        ['предположительно'],
#        ['кодек'],
#        ['предприятия-должник'],
#        ['вавилов'],
#        ['ту'],
#        ['швейный'],
#        ['трубка'],
#        ['голубой'],
#        ['витраж'],
#        ['арматурный'],
#        ['лазо'],
#        ['прядка'],
#        ['мода'],
#        ['железобетон'],
#        ['нога'],
#        ['хмельницкий'],
#        ['as'],
#        ['бти'],
#        ['кольцевой'],
#        ['соединять'],
#        ['гимназия'],
#        ['ю-0'],
#        ['уссурийский'],
#        ['утеплить'],
#        ['т-0/0'],
#        ['си'],
#        ['кронштейн'],
#        ['тихоокеанский'],
#        ['описывать'],
#        ['гу-упф'],
#        ['проходная'],
#        ['куи'],
#        ['театральный'],
#        ['горка'],
#        ['обшить'],
#        ['ответчиком-0'],
#        ['гвардейский'],
#        ['челябинский'],
#        ['взыскателю'],
#        ['komatsu'],
#        ['а-0-0/0'],
#        ['теплоэнергетический'],
#        ['прийтись'],
#        ['evergreen'],
#        ['самара'],
#        ['аллея'],
#        ['веселый'],
#        ['псм'],
#        ['се'],
#        ['гэп'],
#        ['тест'],
#        ['нива'],
#        ['рыбколхоз'],
#        ['заглушка'],
#        ['березовый'],
#        ['прил'],
#        ['прогиб'],
#        ['михайловский'],
#        ['еу'],
#        ['бн'],
#        ['байкальский'],
#        ['далее–'],
#        ['суворов'],
#        ['цветочный'],
#        ['с-0/0'],
#        ['нижеизложенный'],
#        ['душевой'],
#        ['ибо'],
#        ['колясочный'],
#        ['кп-0'],
#        ['енисейский'],
#        ['хк'],
#        ['логан'],
#        ['композиция'],
#        ['пм'],
#        ['задонка'],
#        ['0-ом'],
#        ['социалистический'],
#        ['соя'],
#        ['корс'],
#        ['tga'],
#        ['лиаз'],
#        ['печора'],
#        ['обрабатывать'],
#        ['привокзальный'],
#        ['шпунт'],
#        ['в-0/0'],
#        ['муза'],
#        ['орловский'],
#        ['боковина'],
#        ['жд'],
#        ['пятилетка'],
#        ['касательно'],
#        ['легитимность'],
#        ['peugeot'],
#        ['лодыгин'],
#        ['гп-0'],
#        ['двадцатый'],
#        ['цтп'],
#        ['ман'],
#        ['accent'],
#        ['жертва'],
#        ['звездный'],
#        ['зу'],
#        ['отобразить'],
#        ['виноград'],
#        ['с-0-0'],
#        ['getz'],
#        ['ориентировать'],
#        ['уплачивающего'],
#        ['скол'],
#        ['howo'],
#        ['наконечник'],
#        ['am'],
#        ['егрюла'],
#        ['кровать'],
#        ['опх'],
#        ['хотеть'],
#        ['чехов'],
#        ['енисей'],
#        ['р-0-0'],
#        ['0-аба'],
#        ['незарегистрированный'],
#        ['лиана'],
#        ['ном'],
#        ['rover'],
#        ['matiz'],
#        ['делиться'],
#        ['пр-д'],
#        ['russian'],
#        ['подушка'],
#        ['б-р'],
#        ['техпаспорт'],
#        ['in'],
#        ['сог'],
#        ['инопартнер'],
#        ['строительно'],
#        ['казарма'],
#        ['пустой'],
#        ['авто'],
#        ['новороссийск'],
#        ['шоссейный'],
#        ['менделеев'],
#        ['харьковский'],
#        ['финский'],
#        ['посвятить'],
#        ['тэц-0'],
#        ['to'],
#        ['мф'],
#        ['заречный'],
#        ['лопатка'],
#        ['пробка'],
#        ['называться'],
#        ['антропогенный'],
#        ['fh'],
#        ['снова'],
#        ['0-а'],
#        ['шапка'],
#        ['формализовать'],
#        ['спб'],
#        ['grad'],
#        ['зарезервировать'],
#        ['de'],
#        ['nexia'],
#        ['планово-регулярный'],
#        ['рав'],
#        ['напоминание'],
#        ['разд'],
#        ['теплица'],
#        ['о-0/0'],
#        ['факсограмма'],
#        ['плехановский'],
#        ['замощение'],
#        ['планшет'],
#        ['чп'],
#        ['$'],
#        ['иркутск'],
#        ['инкубатор'],
#        ['правомочность'],
#        ['octavia'],
#        ['казань'],
#        ['тереть'],
#        ['астра'],
#        ['йошкар-ола'],
#        ['липа'],
#        ['пекарня'],
#        ['шайба'],
#        ['пролетарский'],
#        ['настил'],
#        ['кп'],
#        ['zz'],
#        ['моб'],
#        ['f-0'],
#        ['салават'],
#        ['ифнс'],
#        ['газель'],
#        ['бревно'],
#        ['..'],
#        ['camry'],
#        ['lexus'],
#        ['водогрейный'],
#        ['муж'],
#        ['ходовой'],
#        ['автомагистраль'],
#        ['кома'],
#        ['тимирязев'],
#        ['замкнутый'],
#        ['арбитраж\xadный'],
#        ['свиной'],
#        ['помесячно'],
#        ['укрытие'],
#        ['vlz'],
#        ['зем'],
#        ['борозда'],
#        ['ангарский'],
#        ['семьсот'],
#        ['далее-истец'],
#        ['столешница'],
#        ['сейчас'],
#        ['0-ая'],
#        ['шрп'],
#        ['накладываться'],
#        ['виски'],
#        ['ппб-0-0'],
#        ['ммуп'],
#        ['велосипед'],
#        ['извещенных'],
#        ['окраина'],
#        ['армия'],
#        ['cd'],
#        ['арлингтон'],
#        ['пограничник'],
#        ['истома'],
#        ['легальный'],
#        ['правопредшественником'],
#        ['завить'],
#        ['шумерля'],
#        ['медь'],
#        ['зеркальный'],
#        ['категорически'],
#        ['вентиль'],
#        ['ы'],
#        ['вышепоименованный'],
#        ['ер'],
#        ['профильный'],
#        ['снабдить'],
#        ['эксплуатант'],
#        ['конвейер'],
#        ['извещенного'],
#        ['уждт'],
#        ['ремонтно-механический'],
#        ['обложка'],
#        ['ame'],
#        ['неспециализированный'],
#        ['высотный'],
#        ['с-0/0-0'],
#        ['плафа'],
#        ['турбаза'],
#        ['аи'],
#        ['22'],
#        ['субсидирование'],
#        ['windows'],
#        ['заявительница'],
#        ['ремонтно-эксплуатационный'],
#        ['дст-0'],
#        ['мкдоу'],
#        ['радужный'],
#        ['взыскивая'],
#        ['вполне'],
#        ['рш'],
#        ['мех'],
#        ['судостроительный'],
#        ['0-ава'],
#        ['техподполье'],
#        ['абзацев'],
#        ['экономист'],
#        ['фронтальный'],
#        ['дв'],
#        ['одиночный'],
#        ['rostov'],
#        ['днт'],
#        ['задок'],
#        ['председательствовать'],
#        ['береза'],
#        ['недоброкачественный'],
#        ['пирожное'],
#        ['трос'],
#        ['нп'],
#        ['горловина'],
#        ['родина'],
#        ['медпункт'],
#        ['сп-0'],
#        ['команда'],
#        ['блочный'],
#        ['прослеживаться'],
#        ['лев'],
#        ['начислило'],
#        ['шрот'],
#        ['бетонирование'],
#        ['ослабление'],
#        ['vl'],
#        ['минавтотранс'],
#        ['антресольный'],
#        ['клубный'],
#        ['dc'],
#        ['возводиться'],
#        ['исходящий'],
#        ['вакуумный'],
#        ['ти'],
#        ['стан'],
#        ['барнаул'],
#        ['подсветка'],
#        ['сб'],
#        ['дарвин'],
#        ['полка'],
#        ['fb'],
#        ['майский'],
#        ['niva'],
#        ['трехподъездный'],
#        ['мкоу'],
#        ['упоминать'],
#        ['некорректно'],
#        ['съемный'],
#        ['деформировать'],
#        ['astra'],
#        ['сорвать'],
#        ['заморозка'],
#        ['непривлечение'],
#        ['госзаказчик'],
#        ['обвязка'],
#        ['отбензиненный'],
#        ['aquapel'],
#        ['обрезной'],
#        ['30'],
#        ['0/0.'],
#        ['внутригородской'],
#        ['обещать'],
#        ['засо'],
#        ['тухачевский'],
#        ['случиться'],
#        ['томат'],
#        ['зажим'],
#        ['мороженный'],
#        ['сушилка'],
#        ['снимок'],
#        ['fs'],
#        ['снаружи'],
#        ['буквально'],
#        ['уборщица'],
#        ['интернет-клуб'],
#        ['снегоход'],
#        ['инспекторский'],
#        ['высвобождать'],
#        ['владикавказ'],
#        ['антистресс'],
#        ['мужчина'],
#        ['провал'],
#        ['рапортом'],
#        ['абсолютно'],
#        ['ки'],
#        ['дз'],
#        ['командир'],
#        ['конференц-зал'],
#        ['фанера'],
#        ['техникум'],
#        ['декабрист'],
#        ['лесовосстановление'],
#        ['ба'],
#        ['детализировать'],
#        ['mmcjnkb'],
#        ['диван'],
#        ['bdz'],
#        ['натрий'],
#        ['ода'],
#        ['premium'],
#        ['энергоноситель'],
#        ['нефасованный'],
#        ['санитарно-'],
#        ['противопоставить'],
#        ['правобережный'],
#        ['азов'],
#        ['x-trail'],
#        ['бэ'],
#        ['роща'],
#        ['ssangyong'],
#        ['ака'],
#        ['suzuki'],
#        ['внутримуниципальный'],
#        ['юр'],
#        ['оп-0'],
#        ['пк-0'],
#        ['екатеринбургский'],
#        ['кег'],
#        ['мед'],
#        ['лак'],
#        ['створ'],
#        ['электрик'],
#        ['спиртовой'],
#        ['океан'],
#        ['водитель-экспедитор'],
#        ['разделка'],
#        ['шаровой'],
#        ['молодежь'],
#        ['патриот'],
#        ['е-0'],
#        ['обледенение'],
#        ['вовсе'],
#        ['ктм'],
#        ['щербаков'],
#        ['поднятие'],
#        ['пение'],
#        ['ана'],
#        ['панельный'],
#        ['вымерзание'],
#        ['гольф'],
#        ['зд-0'],
#        ['тс-0'],
#        ['взлет'],
#        ['высказывание'],
#        ['агрофирма'],
#        ['приточный'],
#        ['взлетный'],
#        ['агзс'],
#        ['авиатор'],
#        ['м-н'],
#        ['оа-0'],
#        ['токарный'],
#        ['полярный'],
#        ['успеть'],
#        ['иркутский'],
#        ['тф'],
#        ['гидроцилиндр'],
#        ['неэтилированный'],
#        ['кго'],
#        ['ульяновский'],
#        ['плафон'],
#        ['стиральный'],
#        ['блюхер'],
#        ['мотолодка'],
#        ['арка'],
#        ['зональный'],
#        ['плинтус'],
#        ['обводнить'],
#        ['ee'],
#        ['изолятор'],
#        ['емуп'],
#        ['акцент'],
#        ['от\xadветчик'],
#        ['неизбежный'],
#        ['at'],
#        ['шиферный'],
#        ['часто'],
#        ['иж'],
#        ['аб-0'],
#        ['кусок'],
#        ['автошкола'],
#        ['потом'],
#        ['свес'],
#        ['старт'],
#        ['упор'],
#        ['фрахтовщик'],
#        ['коричневый'],
#        ['сочи'],
#        ['феде\xadральный'],
#        ['территориально'],
#        ['ала'],
#        ['пч'],
#        ['москва'],
#        ['джп'],
#        ['ремонт-калькуляция'],
#        ['армированный'],
#        ['цветок'],
#        ['sochi'],
#        ['заложенность'],
#        ['справка-расчет'],
#        ['разин'],
#        ['пэ'],
#        ['мачта'],
#        ['апс'],
#        ['наличествовать'],
#        ['трикотажный'],
#        ['реж'],
#        ['обжалуются'],
#        ['вологдаоблкоммунэнерго'],
#        ['murrey'],
#        ['ржавчина'],
#        ['легитимный'],
#        ['продолжиться'],
#        ['саратовский'],
#        ['отрыть'],
#        ['&'],
#        ['утверждаемыми'],
#        ['гранитный'],
#        ['лет'],
#        ['лорд'],
#        ['крош'],
#        ['буксир'],
#        ['bf'],
#        ['производственно-коммерческий'],
#        ['р-0/0'],
#        ['парфюмерный'],
#        ['очко'],
#        ['тэц'],
#        ['возрасти'],
#        ['лазерный'],
#        ['указанна'],
#        ['митцубиси'],
#        ['fusion'],
#        ['ирк-0-0'],
#        ['смоленский'],
#        ['авианакладная'],
#        ['диспансер'],
#        ['укпг-0'],
#        ['тамбовка'],
#        ['надежда'],
#        ['фотофиксация'],
#        ['црб'],
#        ['волна'],
#        ['hugo'],
#        ['переделка'],
#        ['кромка'],
#        ['распашной'],
#        ['челябинск'],
#        ['импульс'],
#        ['медный'],
#        ['ombrello'],
#        ['металлоизделие'],
#        ['уплатило'],
#        ['электроизмерительный'],
#        ['оборотоспособность'],
#        ['прогнозировать'],
#        ['-0.0.0'],
#        ['эс-0/0'],
#        ['avensis'],
#        ['волос'],
#        ['газо'],
#        ['мтз-0'],
#        ['культиватор'],
#        ['возместив'],
#        ['охлаждать'],
#        ['троицкий'],
#        ['пв'],
#        ['полоска'],
#        ['будка'],
#        ['панфилов'],
#        ['кофейня'],
#        ['док'],
#        ['прачечная'],
#        ['профинансировать'],
#        ['специализация'],
#        ['subaru'],
#        ['зачистка'],
#        ['отправляться'],
#        ['почтальон'],
#        ['феникс'],
#        ['сополимер'],
#        ['нефаза'],
#        ['захламить'],
#        ['бм'],
#        ['соотносить'],
#        ['бригадир'],
#        ['обезличить'],
#        ['организация-контрагент'],
#        ['млп'],
#        ['радуга'],
#        ['непередача'],
#        ['ых'],
#        ['витражный'],
#        ['лодка'],
#        ['фрахтовый'],
#        ['ножницы'],
#        ['автофургон'],
#        ['юо-0'],
#        ['xvii'],
#        ['резина'],
#        ['тротуарный'],
#        ['бакинский'],
#        ['тепличный'],
#        ['хабаровский'],
#        ['оштукатуривание'],
#        ['кресло'],
#        ['зеооэ'],
#        ['игнорирование'],
#        ['задонский'],
#        ['мандарин'],
#        ['зуб'],
#        ['спиртохранилище'],
#        ['наклонный'],
#        ['затвор'],
#        ['следуя'],
#        ['rmb'],
#        ['обувной'],
#        ['нагорный'],
#        ['рэ'],
#        ['каратузский'],
#        ['углубление'],
#        ['девяносто'],
#        ['самореза'],
#        ['нд'],
#        ['кошелек'],
#        ['гипсокартонный'],
#        ['вч'],
#        ['субсидиарно'],
#        ['процессуально'],
#        ['изотоп'],
#        ['смешарика'],
#        ['беоо'],
#        ['работница'],
#        ['su'],
#        ['мучной'],
#        ['огород'],
#        ['0-летний'],
#        ['наставление'],
#        ['мценск'],
#        ['измерить'],
#        ['outlander'],
#        ['lacetti'],
#        ['суворовский'],
#        ['тз'],
#        ['логистический'],
#        ['факел'],
#        ['аца'],
#        ['исполнимый'],
#        ['исчислен'],
#        ['фуражный'],
#        ['подоконник'],
#        ['баржа'],
#        ['энергообъект'],
#        ['едкий'],
#        ['дисковый'],
#        ['неисполнимость'],
#        ['сельхозпроизводитель'],
#        ['чай'],
#        ['буронабивной'],
#        ['рс-0'],
#        ['рай'],
#        ['припарковать'],
#        ['наполнение'],
#        ['кэ'],
#        ['метиз'],
#        ['тюльпан'],
#        ['хоть'],
#        ['ульянов'],
#        ['ню-0'],
#        ['сержант'],
#        ['кисловодск'],
#        ['графитированный'],
#        ['яр'],
#        ['ез'],
#        ['аудио'],
#        ['долина'],
#        ['степан'],
#        ['lzz'],
#        ['рота'],
#        ['ведро'],
#        ['липецк'],
#        ['дуб'],
#        ['некомплектность'],
#        ['армирование'],
#        ['teana'],
#        ['контролироваться'],
#        ['накануне'],
#        ['грузоотправителем'],
#        ['нуз'],
#        ['грязный'],
#        ['гусеница'],
#        ['шарм'],
#        ['freightliner'],
#        ['де'],
#        ['страховка'],
#        ['курский'],
#        ['рыбка'],
#        ['неготовность'],
#        ['бб'],
#        ['комфорт'],
#        ['карьерный'],
#        ['торможение'],
#        ['старшина'],
#        ['кр-0/0-т'],
#        ['л-0/0'],
#        ['пчела'],
#        ['кб'],
#        ['пто'],
#        ['ра-0-0'],
#        ['обжалованные'],
#        ['жалюзи'],
#        ['молния'],
#        ['акриловый'],
#        ['горелка'],
#        ['а-а'],
#        ['дт-0'],
#        ['mp'],
#        ['вятский'],
#        ['адмирал'],
#        ['лицензированный'],
#        ['астраханский'],
#        ['приезжать'],
#        ['внутрироссийский'],
#        ['участь'],
#        ['трижды'],
#        ['пылесос'],
#        ['бензол'],
#        ['кожух'],
#        ['забайкальский'],
#        ['резкий'],
#        ['этикет'],
#        ['ra-0'],
#        ['туфля'],
#        ['сегмент'],
#        ['company'],
#        ['усадьба'],
#        ['винтовой'],
#        ['уп-0'],
#        ['подчеркнуть'],
#        ['койко-место'],
#        ['гайдар'],
#        ['медицина'],
#        ['альмер'],
#        ['лесков'],
#        ['мелочь'],
#        ['выпасть'],
#        ['пенополистирол'],
#        ['гранатовый'],
#        ['артем'],
#        ['оно'],
#        ['универмаг'],
#        ['обезводить'],
#        ['сравниваться'],
#        ['теплоисточник'],
#        ['теплопровод'],
#        ['дозировать'],
#        ['бандероль'],
#        ['предохранитель'],
#        ['рд-0-рсфср-0-0-0-0'],
#        ['светопрозрачный'],
#        ['krasnoyarsk'],
#        ['rexton'],
#        ['расходомер'],
#        ['опираться'],
#        ['кгс'],
#        ['ямз'],
#        ['демократический'],
#        ['меди\xadцинский'],
#        ['ag'],
#        ['спальня'],
#        ['автоцентр'],
#        ['э-0/0-0']], dtype=object), 3: array([['август-сентябрь'],
#        ['февраль-март'],
#        ['май-июнь']], dtype=object)}]

# %%
small_words_CBOW[res==3]
# Out:
# array([['матрос'],
#        ['сержант'],
#        ['солдат'],
#        ['старшина']], dtype=object)

# %%
small_words_CBOW[res==4]
# Out:
# array([['арлингтон'],
#        ['murrey'],
#        ['лорд'],
#        ['кресло']], dtype=object)

# %%
small_words_CBOW[res==5]
# Out:
# array([['менделеев'],
#        ['ангарский'],
#        ['лев'],
#        ['декабрист'],
#        ['щербаков'],
#        ['реж'],
#        ['панфилов'],
#        ['вятский'],
#        ['адмирал'],
#        ['артем']], dtype=object)

# %%
small_words_CBOW[res==6]
# Out:
# array([['однокомнатный'],
#        ['комнатный'],
#        ['0-аба'],
#        ['0-ава'],
#        ['панельный'],
#        ['ез'],
#        ['бб'],
#        ['а-а']], dtype=object)

# %%
small_words_CBOW[res==7]
# Out:
# array([['samara'],
#        ['rostov'],
#        ['юр'],
#        ['р-0/0'],
#        ['задонский'],
#        ['krasnoyarsk']], dtype=object)

# %%
small_words_CBOW[res==8]
# Out:
# array([['арамит'],
#        ['evergreen'],
#        ['плафа']], dtype=object)

# %%
small_words_CBOW[res==9]
# Out:
# array([['октябрь-декабрь'],
#        ['октябрь-ноябрь'],
#        ['январь-апрель'],
#        ['март-апрель'],
#        ['июль-август'],
#        ['лето'],
#        ['сентябрь-октябрь'],
#        ['август-сентябрь'],
#        ['июнь-июль'],
#        ['февраль-март'],
#        ['апрель-май'],
#        ['май-июнь'],
#        ['январь-май'],
#        ['0–0'],
#        ['сентябрь-ноябрь'],
#        ['январь-декабрь'],
#        ['сентябрь-декабрь']], dtype=object)

# %%
small_words_CBOW[res==10]
# Out:
# array([['крош'],
#        ['шарм']], dtype=object)

# %%
for i in range(1, np.max(res)+1):
    print(i, 'кластер: \n', small_words_CBOW[res==i])
# Out:
# 1 кластер:
#  [['хундай']
#  ['corolla']
#  ['хендай']
#  ['субару']
#  ['cr-v']
#  ['skoda']
#  ['королл']
#  ['камри']
#  ['сузука']
#  ['нексия']
#  ['нисан']
#  ['пассат']
#  ['ровер']
#  ['се']
#  ['нива']
#  ['еу']
#  ['логан']
#  ['корс']
#  ['лиаз']
#  ['peugeot']
#  ['ман']
#  ['accent']
#  ['getz']
#  ['rover']
#  ['matiz']
#  ['nexia']
#  ['рав']
#  ['octavia']
#  ['астра']
#  ['camry']
#  ['lexus']
#  ['борозда']
#  ['ер']
#  ['niva']
#  ['astra']
#  ['уборщица']
#  ['x-trail']
#  ['suzuki']
#  ['гольф']
#  ['акцент']
#  ['at']
#  ['иж']
#  ['митцубиси']
#  ['fusion']
#  ['avensis']
#  ['subaru']
#  ['outlander']
#  ['lacetti']
#  ['метиз']
#  ['teana']
#  ['freightliner']
#  ['комфорт']
#  ['альмер']
#  ['маляр']]
# 2 кластер:
#  [['area']
#  ['ed']
#  ['type']
#  ['na']
#  ['zz']
#  ['dc']
#  ['fb']
#  ['заморозка']
#  ['вымерзание']
#  ['ee']
#  ['lzz']
#  ['дуб']]
# 3 кластер:
#  [['матрос']
#  ['сержант']
#  ['солдат']
#  ['старшина']]
# 4 кластер:
#  [['арлингтон']
#  ['murrey']
#  ['лорд']
#  ['кресло']]
# 5 кластер:
#  [['менделеев']
#  ['ангарский']
#  ['лев']
#  ['декабрист']
#  ['щербаков']
#  ['реж']
#  ['панфилов']
#  ['вятский']
#  ['адмирал']
#  ['артем']]
# 6 кластер:
#  [['однокомнатный']
#  ['комнатный']
#  ['0-аба']
#  ['0-ава']
#  ['панельный']
#  ['ез']
#  ['бб']
#  ['а-а']]
# 7 кластер:
#  [['samara']
#  ['rostov']
#  ['юр']
#  ['р-0/0']
#  ['задонский']
#  ['krasnoyarsk']]
# 8 кластер:
#  [['арамит']
#  ['evergreen']
#  ['плафа']]
# 9 кластер:
#  [['октябрь-декабрь']
#  ['октябрь-ноябрь']
#  ['январь-апрель']
#  ['март-апрель']
#  ['июль-август']
#  ['лето']
#  ['сентябрь-октябрь']
#  ['август-сентябрь']
#  ['июнь-июль']
#  ['февраль-март']
#  ['апрель-май']
#  ['май-июнь']
#  ['январь-май']
#  ['0–0']
#  ['сентябрь-ноябрь']
#  ['январь-декабрь']
#  ['сентябрь-декабрь']]
# 10 кластер:
#  [['крош']
#  ['шарм']]
# 11 кластер:
#  [['кронштейн']
#  ['задок']
#  ['арка']
#  ['плинтус']]
# 12 кластер:
#  [['коричневый']
#  ['полоска']
#  ['акриловый']]
# 13 кластер:
#  [['глазной']
#  ['сироп']
#  ['инъекция']
#  ['дозировать']]
# 14 кластер:
#  [['медпункт']
#  ['прачечная']
#  ['универмаг']]
# 15 кластер:
#  [['неэтичный']
#  ['нечестный']
#  ['поступок']]
# 16 кластер:
#  [['азот']
#  ['диоксид']
#  ['углерод']]
# 17 кластер:
#  [['люкс']
#  ['маковый']
#  ['начинка']
#  ['рулет']]
# 18 кластер:
#  [['подстанция']
#  ['трансформаторный']
#  ['электропередача']
#  ['пс']
#  ['тп']
#  ['ква']
#  ['тп-0']
#  ['вл-0']
#  ['кл']
#  ['ктп']
#  ['кл-0']
#  ['фидер']
#  ['яч']
#  ['ру-0']
#  ['вл-0,0']
#  ['ру-0,0']]
# 19 кластер:
#  [['швейный']
#  ['пирожное']
#  ['макаронный']
#  ['трикотажный']
#  ['мучной']]
# 20 кластер:
#  [['сын']
#  ['мать']
#  ['дочь']
#  ['жена']
#  ['муж']
#  ['отец']]
# 21 кластер:
#  [['седьмой']
#  ['восьмой']
#  ['одиннадцатый']
#  ['двенадцатый']
#  ['четырнадцатый']
#  ['тринадцатый']
#  ['шестнадцатый']]
# 22 кластер:
#  [['сорный']
#  ['древесно-кустарниковый']
#  ['зарастание']]
# 23 кластер:
#  [['волга']
#  ['каспий']]
# 24 кластер:
#  [['приемки-сдачи']
#  ['сдача-прием']
#  ['приема-сдача']]
# 25 кластер:
#  [['товароведческий']
#  ['автотехнический']
#  ['автотовароведческий']
#  ['судебно-технический']
#  ['судебно-бухгалтерский']]
# 26 кластер:
#  [['xviii']
#  ['xix']
#  ['xii']
#  ['xvii']]
# 27 кластер:
#  [['вкх']
#  ['жилищно-эксплуатационный']
#  ['xxii']
#  ['лицензированный']]
# 28 кластер:
#  [['примерно']
#  ['юго-восток']
#  ['юго-запад']
#  ['север']
#  ['северо-запад']
#  ['запад']
#  ['восток']
#  ['северо-восток']
#  ['юг']]
# 29 кластер:
#  [['рсфср']
#  ['коллективно-долевой']
#  ['ссср']
#  ['общедолевой']]
# 30 кластер:
#  [['ида']
#  ['фкрс']
#  ['фкд-0/0']]
# 31 кластер:
#  [['сличительный']
#  ['сверочный']
#  ['сальдовый']]
# 32 кластер:
#  [['экономика']
#  ['коньяк']
#  ['звездочка']
#  ['пятилетний']
#  ['шампанское']
#  ['автостраховщик']]
# 33 кластер:
#  [['оттиском']
#  ['заверять']
#  ['оттиска']
#  ['гербовый']]
# 34 кластер:
#  [['торгово-закупочный']
#  ['сыскной']
#  ['лицензируемой']
#  ['воспитательный']]
# 35 кластер:
#  [['пени-']
#  ['составляет-']
#  ['долга-']]
# 36 кластер:
#  [['ролик']
#  ['плакат']
#  ['листовка']]
# 37 кластер:
#  [['лейтенант']
#  ['госинспектор']
#  ['оперуполномоченный']
#  ['майор']]
# 38 кластер:
#  [['выставочный']
#  ['мирный']
#  ['подъездной']
#  ['крановый']
#  ['подкрановый']]
# 39 кластер:
#  [['соревнование']
#  ['концерт']
#  ['фестиваль']]
# 40 кластер:
#  [['ээ']
#  ['эь']
#  ['эч']
#  ['эы']
#  ['эш']
#  ['эя']]
# 41 кластер:
#  [['0.0.0']
#  ['март']
#  ['декабрь']
#  ['январь']
#  ['апрель']
#  ['октябрь']
#  ['июль']
#  ['ноябрь']
#  ['май']
#  ['февраль']
#  ['июнь']
#  ['август']
#  ['сентябрь']]
# 42 кластер:
#  [['литер']
#  ['лит']
#  ['литера']]
# 43 кластер:
#  [['следовать']
#  ['усматриваться']
#  ['видно']]
# 44 кластер:
#  [['аукцион']
#  ['торг']
#  ['конкурс']]
# 45 кластер:
#  [['отклоняться']
#  ['отклонить']
#  ['отклонять']]
# 46 кластер:
#  [['статья']
#  ['ст']
#  ['стать']]
