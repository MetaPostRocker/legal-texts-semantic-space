# %%
import Wishart
from Wishart import Wishart
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.metrics import calinski_harabasz_score
import pickle
from sklearn.cluster import KMeans
from s_dbw import SD

# %%
#https://github.com/intelligent-environments-lab/ProfileClustering/blob/master/Clustering%20Analysis/Clustering%20Validation%20Metrics.ipynb
# метрики взяты с этого сайта 
def divide(data, labels):
    clusters = set(labels)
    clusters_data = []
    for cluster in clusters:
        clusters_data.append(data[labels == cluster, :])
    return clusters_data

def get_centroids(clusters):
    centroids = []
    for cluster_data in clusters:
        centroids.append(cluster_data.mean(axis=0))
    return centroids

def SST(data):
    c = get_centroids([data])
    return ((data - c) ** 2).sum()

def SSE(clusters, centroids):
    result = 0
    for cluster, centroid in zip(clusters, centroids):
        result += ((cluster - centroid) ** 2).sum()
    return result

# Clear the store before running each time
within_cluster_dist_sum_store = {}
def within_cluster_dist_sum(cluster, centroid, cluster_id):
    if cluster_id in within_cluster_dist_sum_store:
        return within_cluster_dist_sum_store[cluster_id]
    else:
        result = (((cluster - centroid) ** 2).sum(axis=1)**.5).sum()
        within_cluster_dist_sum_store[cluster_id] = result
    return result

def RMSSTD(data, clusters, centroids):
    df = data.shape[0] - len(clusters)
    attribute_num = data.shape[1]
    return (SSE(clusters, centroids) / (attribute_num * df)) ** .5

# equal to separation / (cohesion + separation)
def RS(data, clusters, centroids):
    sst = SST(data)
    sse = SSE(clusters, centroids)
    return (sst - sse) / sst

def DB_find_max_j(clusters, centroids, i):
    max_val = 0
    max_j = 0
    for j in range(len(clusters)):
        if j == i:
            continue
        cluster_i_stat = within_cluster_dist_sum(clusters[i], centroids[i], i) / clusters[i].shape[0]
        cluster_j_stat = within_cluster_dist_sum(clusters[j], centroids[j], j) / clusters[j].shape[0]
        val = (cluster_i_stat + cluster_j_stat) / (((centroids[i] - centroids[j]) ** 2).sum() ** .5)
        if val > max_val:
            max_val = val
            max_j = j
    return max_val

def DB(data, clusters, centroids):
    result = 0
    for i in range(len(clusters)):
        result += DB_find_max_j(clusters, centroids, i)
    return result / len(clusters)

def XB(data, clusters, centroids):
    sse = SSE(clusters, centroids)
    min_dist = ((centroids[0] - centroids[1]) ** 2).sum()
    for centroid_i, centroid_j in list(product(centroids, centroids)):
        if (centroid_i - centroid_j).sum() == 0:
            continue
        dist = ((centroid_i - centroid_j) ** 2).sum()
        if dist < min_dist:
            min_dist = dist
    return sse / (data.shape[0] * min_dist)

def inter_cluster_distances(labels, distances, method='nearest'):
    """Calculates the distances between the two nearest points of each cluster.
    :param labels: a list containing cluster labels for each of the n elements
    :param distances: an n x n numpy.array containing the pairwise distances between elements
    :param method: `nearest` for the distances between the two nearest points in each cluster, or `farthest`
    """
    
    
    CLUSTER_DISTANCE_METHODS = ['nearest', 'farthest']
    
    if method not in CLUSTER_DISTANCE_METHODS:
        raise ValueError(
            'method must be one of {}'.format(CLUSTER_DISTANCE_METHODS))

    if method == 'nearest':
        return __cluster_distances_by_points(labels, distances)
    elif method == 'farthest':
        return __cluster_distances_by_points(labels, distances, farthest=True)


def __cluster_distances_by_points(labels, distances, farthest=False):
    n_unique_labels = len(np.unique(labels))
    cluster_distances = np.full((n_unique_labels, n_unique_labels),
                                float('inf') if not farthest else 0)

    np.fill_diagonal(cluster_distances, 0)

    for i in np.arange(0, len(labels) - 1):
        for ii in np.arange(i, len(labels)):
            if labels[i] != labels[ii] and (
                (not farthest and
                 distances[i, ii] < cluster_distances[labels[i], labels[ii]])
                    or
                (farthest and
                 distances[i, ii] > cluster_distances[labels[i], labels[ii]])):
                cluster_distances[labels[i], labels[ii]] = cluster_distances[
                    labels[ii], labels[i]] = distances[i, ii]
    return cluster_distances


def diameter(labels, distances, method='farthest'):
    """Calculates cluster diameters
    :param labels: a list containing cluster labels for each of the n elements
    :param distances: an n x n numpy.array containing the pairwise distances between elements
    :param method: either `mean_cluster` for the mean distance between all elements in each cluster, or `farthest` for the distance between the two points furthest from each other
    """
    DIAMETER_METHODS = ['mean_cluster', 'farthest']
    if method not in DIAMETER_METHODS:
        raise ValueError('method must be one of {}'.format(DIAMETER_METHODS))

    n_clusters = len(np.unique(labels))
    diameters = np.zeros(n_clusters)

    if method == 'mean_cluster':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii]:
                    diameters[labels[i]] += distances[i, ii]

        for i in range(len(diameters)):
            diameters[i] /= sum(labels == i)

    elif method == 'farthest':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii] and distances[i, ii] > diameters[
                        labels[i]]:
                    diameters[labels[i]] = distances[i, ii]
    return diameters


def dunn(data, labels, diameter_method='farthest',
         cdist_method='nearest'):
    distances = euclidean_distances(data)
    """
    Dunn index for cluster validation (larger is better).
    
    .. math:: D = \\min_{i = 1 \\ldots n_c; j = i + 1\ldots n_c} \\left\\lbrace \\frac{d \\left( c_i,c_j \\right)}{\\max_{k = 1 \\ldots n_c} \\left(diam \\left(c_k \\right) \\right)} \\right\\rbrace
    
    where :math:`d(c_i,c_j)` represents the distance between
    clusters :math:`c_i` and :math:`c_j`, and :math:`diam(c_k)` is the diameter of cluster :math:`c_k`.
    Inter-cluster distance can be defined in many ways, such as the distance between cluster centroids or between their closest elements. Cluster diameter can be defined as the mean distance between all elements in the cluster, between all elements to the cluster centroid, or as the distance between the two furthest elements.
    The higher the value of the resulting Dunn index, the better the clustering
    result is considered, since higher values indicate that clusters are
    compact (small :math:`diam(c_k)`) and far apart (large :math:`d \\left( c_i,c_j \\right)`).
    :param labels: a list containing cluster labels for each of the n elements
    :param distances: an n x n numpy.array containing the pairwise distances between elements
    :param diameter_method: see :py:function:`diameter` `method` parameter
    :param cdist_method: see :py:function:`diameter` `method` parameter
    
    .. [Kovacs2005] Kovács, F., Legány, C., & Babos, A. (2005). Cluster validity measurement techniques. 6th International Symposium of Hungarian Researchers on Computational Intelligence.
    """

    labels = LabelEncoder().fit(labels).transform(labels)

    ic_distances = inter_cluster_distances(labels, distances, cdist_method)
    min_distance = min(ic_distances[ic_distances.nonzero()])
    max_diameter = max(diameter(labels, distances, diameter_method))

    return min_distance / max_diameter

def mod_hubert_statistic(data, clusters, centroids):
    index = 0 
    for i in range(len(clusters)):
        for j in range(len(clusters)):
            if i == j:
                continue
            
            d_c = np.linalg.norm(np.array(centroids[i]) - np.array(centroids[j]))
            for x in clusters[i]:
                for y in clusters[j]:
                    index += np.linalg.norm(np.array(x) - np.array(y)) * d_c
    return index * 2 /(len(data) * (len(data) - 1))

def i_index(data, clusters, centroids):
    c = data.mean(axis=0)
    sum_d_c = np.sum(np.linalg.norm(data - c, axis=1))
    m = 0
    for i in range(len(centroids)):
        for j in range(i + 1, len(centroids)):
            m = max(m, np.linalg.norm(centroids[i] - centroids[j]))
    s = 0
    for i in range(len(clusters)):
        s += np.sum(np.linalg.norm(clusters[i] - centroids[i], axis=1))
    return (sum_d_c * m / (len(clusters) * s))**len(data[0])

def Sep(labels, k, dk, dist):
    clusters = sorted(set(labels))
    max_sep = None
    for cluster in clusters:
        cluster_data = dist[labels == cluster]
        cluster_data = cluster_data[:, labels != cluster]
        cluster_dk = dk[labels == cluster]
        sep = len(cluster_data[cluster_data <= np.c_[cluster_dk]]) / (k * cluster_data.shape[0])
        if max_sep is None or max_sep < sep:
            max_sep = sep
    return max_sep

def Com(labels, dist):
    clusters = sorted(set(labels))
    com = 0
    max_com = 0
    for cluster in clusters:
        cluster_data = dist[labels == cluster]
        cluster_data = cluster_data[:, labels == cluster]
        n_i = cluster_data.shape[0]
#        print(n_i, cluster_data.sum())
        if n_i > 1:
            cur_sum = 2 * cluster_data.sum() / (n_i * (n_i - 1))
            com += cur_sum
            if max_com < cur_sum:
                max_com = cur_sum
    return com, max_com

def CVNN(labels, k, dk, dist):
    com, max_com = Com(labels, dist)
    return Sep(labels, k, dk, dist) + com / max_com 

def get_validation_scores(data, labels, k, dk, dist):
    within_cluster_dist_sum_store.clear()
    
    clusters = divide(data, labels)
    centroids = get_centroids(clusters)
    
    scores = {}
#     scores['1 RMSSTD'] = RMSSTD(data, clusters, centroids)
    scores['RS'] = RS(data, clusters, centroids)
#     scores['3 H'] = mod_hubert_statistic(data, clusters, centroids)
#     scores['CH'] = calinski_harabasz_score(data, labels)
#     scores['5 I'] = i_index(data, clusters, centroids)
#     scores['6 D'] = dunn(data, labels)
#     scores['7 S'] = silhouette_score(data, labels)
#     scores['8 DB'] = DB(data, clusters, centroids)
    scores['XB'] = XB(data, clusters, centroids)
    scores['SD'] = SD(data, labels)
#     scores['11 S_Dbw'] = S_Dbw(data, labels)
#     scores['12 CVNN'] = CVNN(labels, k, dk, dist)
    return scores

# %%
# Скачиваем словарь слов - эмбедингов SKIP Gram
dictionary_SKIP = pickle.load(open("dictionary_skip_gramm.pkl", 'rb'))

# %%
# Достаем эмбединги
dict_SKIP = dictionary_SKIP.values()
dict_SKIP = np.array(list(dict_SKIP))

# %%
type(dict_SKIP[0])
# Out:
# numpy.ndarray

# %%
# Возьмем подвыборку для обучения
small_dict_SKIP1 = np.array(pd.DataFrame(dict_SKIP).loc[:10000])
small_dict_SKIP2 = np.array(pd.DataFrame(dict_SKIP).loc[20000:40000])
small_dict_SKIP3 = np.array(pd.DataFrame(dict_SKIP).loc[40000:])

# %%
words_SKIP = dictionary_SKIP.keys()
words_SKIP = np.array(list(words_SKIP))
small_words_SKIP1 = np.array(pd.DataFrame(words_SKIP).loc[:10000])
small_words_SKIP2 = np.array(pd.DataFrame(words_SKIP).loc[20000:40000])
small_words_SKIP3 = np.array(pd.DataFrame(words_SKIP).loc[40000:])

# %%
# Запустим алгоритм кластеризации Wishart на этой подвыборке
datasets_clustering = []
datasets_names = []
num_clusters = 5
k = 2
while num_clusters >= 5:
    WC = Wishart(k, 0.001)
    res = WC.fit(small_dict_SKIP1)
    num_clusters = np.max(res)
    print(num_clusters)
    datasets_clustering.append((small_dict_SKIP1, WC))
    datasets_names += ['k = ' + str(k)]
    k += 1
# Out:
# Start clustering
# 180
# Start clustering
# 82
# Start clustering
# 42
# Start clustering
# 33
# Start clustering
# 27
# Start clustering
# 19
# Start clustering
# 15
# Start clustering
# 15
# Start clustering
# 13
# Start clustering
# 11
# Start clustering
# 9
# Start clustering
# 8
# Start clustering
# 7
# Start clustering
# 7
# Start clustering
# 6
# Start clustering
# 6
# Start clustering
# 6
# Start clustering
# 6
# Start clustering
# 6
# Start clustering
# 6
# Start clustering
# 6
# Start clustering
# 5
# Start clustering
# 5
# Start clustering
# 5
# Start clustering
# 5
# Start clustering
# 5
# Start clustering
# 5
# Start clustering
# 5
# Start clustering
# 5
# Start clustering
# 5
# Start clustering
# 4

# %%
from itertools import combinations, product
scores_list = []
dict_list = [] # список словарей 
for (data, WC), data_name in zip(datasets_clustering, datasets_names):
#     print(data_name)
    if(len(set(WC.object_labels)) == 1):
        print('Set with one cluster')
        continue
#     print(len(set(WC.object_labels)))
    scores = get_validation_scores(data, WC.object_labels, k=10, dk=WC.dk_, dist=WC.dist_)
    scores_list += [scores]
#     for key in scores: 
#         print('\t' + key + ': %.4f' % scores[key])
    dict_ = {}
    for i in set(WC.object_labels):
        dict_[i] =  small_words_SKIP1[WC.object_labels==i]
    dict_list += [dict_]

# %%
datasets_names
# Out:
# ['k = 2',
#  'k = 3',
#  'k = 4',
#  'k = 5',
#  'k = 6',
#  'k = 7',
#  'k = 8',
#  'k = 9',
#  'k = 10',
#  'k = 11',
#  'k = 12',
#  'k = 13',
#  'k = 14',
#  'k = 15',
#  'k = 16',
#  'k = 17',
#  'k = 18',
#  'k = 19',
#  'k = 20',
#  'k = 21',
#  'k = 22',
#  'k = 23',
#  'k = 24',
#  'k = 25',
#  'k = 26',
#  'k = 27',
#  'k = 28',
#  'k = 29',
#  'k = 30',
#  'k = 31',
#  'k = 32']

# %%
from collections import defaultdict
metrics_k_grid = defaultdict(list)
k_grid = np.arange(2, 33, 1)
for i in range(len(scores_list)):
    scores = scores_list[i]
    for key in scores:
        metrics_k_grid[key].append(scores[key])

# %%
len(metrics_k_grid['RS'])
# Out:
# 31

# %%
fig, axs = plt.subplots(3, figsize=(4,12))
for i in range(3):
    if i == 0: axs[i].set_title('Skip Gram clustering metrics')
    metricname = list(metrics_k_grid.keys())[i]
    y = metrics_k_grid[metricname]
    axs[i].set_xlabel('k')
    axs[i].set_ylabel(metricname)
    axs[i].plot(k_grid[:len(y)], y)

# %%
dict_list[0]
# Out:
# {0: array([['дело'],
#         ['договор'],
#         ['за'],
#         ...,
#         ['ag'],
#         ['экг'],
#         ['э-0/0-0']], dtype=object),
#  1: array([['г'],
#         ['0.0.0'],
#         ['год'],
#         ['март'],
#         ['декабрь'],
#         ['январь'],
#         ['апрель'],
#         ['октябрь'],
#         ['июль'],
#         ['ноябрь'],
#         ['май'],
#         ['февраль'],
#         ['июнь'],
#         ['август'],
#         ['сентябрь']], dtype=object),
#  2: array([['опель'],
#         ['мицубиси'],
#         ['рено'],
#         ['шевроле'],
#         ['мерседес'],
#         ['пежо'],
#         ['рр'],
#         ['хонда'],
#         ['ке'],
#         ['ауди'],
#         ['land'],
#         ['ое'],
#         ['лада'],
#         ['дэу'],
#         ['рх'],
#         ['фокус'],
#         ['хм'],
#         ['хо'],
#         ['хендэ'],
#         ['уу'],
#         ['logan'],
#         ['ох'],
#         ['уе'],
#         ['cruiser'],
#         ['лансер'],
#         ['daewoo'],
#         ['volkswagen'],
#         ['шкода'],
#         ['honda'],
#         ['ху'],
#         ['ленд'],
#         ['хе'],
#         ['sr'],
#         ['benz'],
#         ['mercedes'],
#         ['audi'],
#         ['lancer'],
#         ['хн'],
#         ['scania'],
#         ['хундай'],
#         ['opel'],
#         ['focus'],
#         ['rav'],
#         ['сканий'],
#         ['corolla'],
#         ['крузер'],
#         ['хендай'],
#         ['бенц'],
#         ['субару'],
#         ['cr-v'],
#         ['skoda'],
#         ['королл'],
#         ['камри'],
#         ['маз-0'],
#         ['фиат'],
#         ['сузука'],
#         ['нексия'],
#         ['нисан'],
#         ['пассат'],
#         ['ровер'],
#         ['се'],
#         ['еу'],
#         ['логан'],
#         ['корс'],
#         ['tga'],
#         ['лиаз'],
#         ['peugeot'],
#         ['ман'],
#         ['accent'],
#         ['getz'],
#         ['rover'],
#         ['matiz'],
#         ['nexia'],
#         ['рав'],
#         ['octavia'],
#         ['астра'],
#         ['camry'],
#         ['lexus'],
#         ['niva'],
#         ['astra'],
#         ['x-trail'],
#         ['suzuki'],
#         ['акцент'],
#         ['иж'],
#         ['митцубиси'],
#         ['fusion'],
#         ['avensis'],
#         ['subaru'],
#         ['нефаза'],
#         ['outlander'],
#         ['lacetti'],
#         ['teana'],
#         ['freightliner'],
#         ['альмер']], dtype=object),
#  5: array([['i-0.'],
#         ['арамит'],
#         ['evergreen'],
#         ['плафа']], dtype=object),
#  6: array([['фут'],
#         ['арлингтон'],
#         ['murrey'],
#         ['лорд']], dtype=object),
#  7: array([['военно-учетный'],
#         ['переподготовка'],
#         ['матрос'],
#         ['сержант'],
#         ['солдат'],
#         ['старшина']], dtype=object),
#  8: array([['0'],
#         ['в'],
#         ['и'],
#         ['3'],
#         ['4'],
#         ['с'],
#         ['по'],
#         ['1'],
#         ['на'],
#         ['о'],
#         ['от'],
#         ['не'],
#         ['№'],
#         ['суд'],
#         ['статья'],
#         ['ответчик'],
#         ['что'],
#         ['истец'],
#         ['ст'],
#         ['установить'],
#         ['пункт'],
#         ['при'],
#         ['а'],
#         ['указать'],
#         ['согласно'],
#         ['общество'],
#         ['услуга'],
#         ['п'],
#         ['также'],
#         ['такой'],
#         ['заявитель'],
#         ['данный'],
#         ['л'],
#         ['поскольку'],
#         ['вывод'],
#         ['спорный'],
#         ['так'],
#         ['кроме'],
#         ['назвать'],
#         ['прийти'],
#         ['однако'],
#         ['следовательно'],
#         ['реализация'],
#         ['именно'],
#         ['указывать'],
#         ['согласовать'],
#         ['указанный'],
#         ['вместе'],
#         ['частично'],
#         ['вышеуказанный'],
#         ['полностью'],
#         ['то'],
#         ['поэтому'],
#         ['пояснить'],
#         ['том'],
#         ['отразить'],
#         ['реализовать'],
#         ['податель'],
#         ['вышеназванный'],
#         ['отметить'],
#         ['отмечать'],
#         ['44'],
#         ['оговорить'],
#         ['указ'],
#         ['действительно'],
#         ['апеллянт'],
#         ['губернатор'],
#         ['приостанавливаться'],
#         ['навязывание'],
#         ['приостанавливать'],
#         ['единогласно'],
#         ['указный'],
#         ['отраженный'],
#         ['проголосовать'],
#         ['дискриминационный'],
#         ['слуга'],
#         ['кассатор'],
#         ['правомочность'],
#         ['истома'],
#         ['толковать'],
#         ['покинуть'],
#         ['буквально'],
#         ['приезд'],
#         ['легитимный'],
#         ['уп-0'],
#         ['подчеркнуть']], dtype=object),
#  9: array([['неэтичный'],
#         ['нечестный'],
#         ['поступок']], dtype=object),
#  10: array([['ve'],
#         ['tic'],
#         ['sti'],
#         ['company']], dtype=object),
#  11: array([['карл'],
#         ['гоголь'],
#         ['набережный'],
#         ['фрунзе'],
#         ['шевченко'],
#         ['генерал'],
#         ['орджоникидзе'],
#         ['революция'],
#         ['урицкий'],
#         ['володарский'],
#         ['интернациональный'],
#         ['марта'],
#         ['королева'],
#         ['толстой'],
#         ['академик'],
#         ['чернышевский'],
#         ['циолковский'],
#         ['революционный'],
#         ['металлург'],
#         ['пирогов'],
#         ['герцен'],
#         ['цвиллинг'],
#         ['вокзальный'],
#         ['тургенев'],
#         ['крупский'],
#         ['пр-кт'],
#         ['расплодить'],
#         ['маяковский'],
#         ['нахимов'],
#         ['хмельницкий'],
#         ['театральный'],
#         ['куйбышев'],
#         ['гвардейский'],
#         ['аллея'],
#         ['березовый'],
#         ['байкальский'],
#         ['суворов'],
#         ['социалистический'],
#         ['ворошилов'],
#         ['привокзальный'],
#         ['пятилетка'],
#         ['звездный'],
#         ['чехов'],
#         ['пр-д'],
#         ['б-р'],
#         ['шоссейный'],
#         ['менделеев'],
#         ['харьковский'],
#         ['плехановский'],
#         ['пролетарский'],
#         ['тимирязев'],
#         ['батарейный'],
#         ['ангарский'],
#         ['0-ая'],
#         ['армия'],
#         ['пограничник'],
#         ['емельяново'],
#         ['судостроительный'],
#         ['родина'],
#         ['медпункт'],
#         ['лев'],
#         ['дарвин'],
#         ['тухачевский'],
#         ['декабрист'],
#         ['азов'],
#         ['щербаков'],
#         ['авиатор'],
#         ['м-н'],
#         ['полярный'],
#         ['блюхер'],
#         ['достоевский'],
#         ['разин'],
#         ['реж'],
#         ['лет'],
#         ['тамбовка'],
#         ['панфилов'],
#         ['прачечная'],
#         ['бакинский'],
#         ['тепличный'],
#         ['каратузский'],
#         ['мценск'],
#         ['суворовский'],
#         ['ульянов'],
#         ['кисловодск'],
#         ['степан'],
#         ['боксовый'],
#         ['0-летия'],
#         ['вятский'],
#         ['адмирал'],
#         ['гайдар'],
#         ['лесков'],
#         ['артем'],
#         ['универмаг'],
#         ['автоцентр']], dtype=object),
#  12: array([['капля'],
#         ['порошок'],
#         ['собака'],
#         ['капсула'],
#         ['уп'],
#         ['кошка'],
#         ['флакон'],
#         ['внутрь'],
#         ['крем'],
#         ['мазь'],
#         ['ингаляция'],
#         ['глазной'],
#         ['суспензия'],
#         ['сироп'],
#         ['блоха'],
#         ['инъекция'],
#         ['спиртовой'],
#         ['дозировать']], dtype=object),
#  13: array([['ат-0/0'],
#         ['sys'],
#         ['дст'],
#         ['vlz'],
#         ['дст-0'],
#         ['vl']], dtype=object),
#  15: array([['следовать'],
#         ['усматриваться'],
#         ['видно'],
#         ['нижеизложенный']], dtype=object),
#  16: array([['сайт'],
#         ['интернет-сайт'],
#         ['zakupki'],
#         ['веб-адрес'],
#         ['samara'],
#         ['saratov'],
#         ['grad'],
#         ['rostov'],
#         ['krasnoyarsk']], dtype=object),
#  17: array([['январь-февраль'],
#         ['январь-март'],
#         ['октябрь-декабрь'],
#         ['октябрь-ноябрь'],
#         ['январь-апрель'],
#         ['март-апрель'],
#         ['июль-август'],
#         ['сентябрь-октябрь'],
#         ['август-сентябрь'],
#         ['июнь-июль'],
#         ['февраль-март'],
#         ['апрель-май'],
#         ['май-июнь'],
#         ['январь-май'],
#         ['сентябрь-ноябрь'],
#         ['январь-декабрь'],
#         ['сентябрь-декабрь']], dtype=object),
#  18: array([['0-аа'],
#         ['0-аба'],
#         ['0-ава'],
#         ['ба'],
#         ['ала'],
#         ['ез'],
#         ['бб']], dtype=object),
#  19: array([['ориентир'],
#         ['примерно'],
#         ['юго-восток'],
#         ['юго-запад'],
#         ['север'],
#         ['северо-запад'],
#         ['запад'],
#         ['восток'],
#         ['северо-восток'],
#         ['юг']], dtype=object),
#  20: array([['оконный'],
#         ['дверной'],
#         ['пробивка'],
#         ['потолочный'],
#         ['настил'],
#         ['борозда'],
#         ['бетонирование'],
#         ['плафон'],
#         ['плинтус'],
#         ['шиферный'],
#         ['свес'],
#         ['витражный'],
#         ['акриловый'],
#         ['винтовой'],
#         ['светопрозрачный'],
#         ['штепсельный']], dtype=object),
#  21: array([['area'],
#         ['ed'],
#         ['type'],
#         ['fb'],
#         ['ee']], dtype=object),
#  22: array([['боковина'],
#         ['скол'],
#         ['задок'],
#         ['деформировать']], dtype=object),
#  23: array([['оксид'],
#         ['азот'],
#         ['сера'],
#         ['алюминий'],
#         ['диоксид'],
#         ['частица'],
#         ['углерод']], dtype=object),
#  24: array([['na'],
#         ['zz'],
#         ['мтз-0'],
#         ['lzz'],
#         ['дт-0'],
#         ['ямз']], dtype=object),
#  25: array([['анимационный'],
#         ['маша'],
#         ['фонетический'],
#         ['семантический'],
#         ['треугольник'],
#         ['russian'],
#         ['boss'],
#         ['мультипликационный'],
#         ['aquapel'],
#         ['антистресс'],
#         ['противопоставить'],
#         ['felerro'],
#         ['sochi'],
#         ['крош'],
#         ['hugo'],
#         ['marketing'],
#         ['полоска'],
#         ['латинский'],
#         ['наклонный'],
#         ['смешарика'],
#         ['шарм'],
#         ['этикет']], dtype=object),
#  29: array([['костюм'],
#         ['футболка'],
#         ['брюки'],
#         ['куртка'],
#         ['шорты'],
#         ['кроссовок'],
#         ['наручный'],
#         ['кошелек']], dtype=object),
#  30: array([['ктп'],
#         ['фидер'],
#         ['яч'],
#         ['ру-0'],
#         ['отходить'],
#         ['вл-0,0'],
#         ['низковольтный'],
#         ['ру-0,0'],
#         ['рп-0']], dtype=object),
#  31: array([['раковина'],
#         ['запирать'],
#         ['умывальник'],
#         ['отрегулировать'],
#         ['унитаз'],
#         ['умывальный'],
#         ['спальня']], dtype=object),
#  33: array([['ида'],
#         ['фкрс'],
#         ['бул-сб'],
#         ['idd'],
#         ['своо'],
#         ['фкд-0/0'],
#         ['с-0/0-0'],
#         ['уввк-0']], dtype=object),
#  34: array([['сдача-приемка'],
#         ['прием-сдача'],
#         ['приемка-сдача'],
#         ['приемке'],
#         ['приемки-сдачи'],
#         ['сдачи-'],
#         ['неподписанный'],
#         ['сдача-прием'],
#         ['приема-сдача'],
#         ['кс-0,']], dtype=object),
#  35: array([['руб'],
#         ['сумма'],
#         ['размер'],
#         ['копа'],
#         ['рубль'],
#         ['составлять'],
#         ['копейка'],
#         ['всего'],
#         ['сума']], dtype=object),
#  36: array([['брат'],
#         ['усыновить'],
#         ['усыновитель'],
#         ['полнородный'],
#         ['неполнородный'],
#         ['родство']], dtype=object),
#  39: array([['пристрой'],
#         ['пристроить'],
#         ['торгово-административный'],
#         ['административно-торговый'],
#         ['девятиэтажный'],
#         ['встроенно-пристроенный'],
#         ['четырехэтажный'],
#         ['трехподъездный'],
#         ['панельный']], dtype=object),
#  40: array([['челябинский'],
#         ['ульяновский'],
#         ['саратовский'],
#         ['курский'],
#         ['астраханский'],
#         ['забайкальский']], dtype=object),
#  42: array([['консервы'],
#         ['куриный'],
#         ['охладить'],
#         ['торт'],
#         ['кишечный'],
#         ['сгустить'],
#         ['тушеный'],
#         ['пирожное'],
#         ['палочка'],
#         ['печень'],
#         ['инфекция'],
#         ['чума']], dtype=object),
#  43: array([['сосна'],
#         ['береза'],
#         ['обрезной'],
#         ['дуб']], dtype=object),
#  45: array([['автогараж'],
#         ['будка'],
#         ['а-а']], dtype=object),
#  46: array([['сын'],
#         ['мать'],
#         ['дочь'],
#         ['жена'],
#         ['муж'],
#         ['отец'],
#         ['родный']], dtype=object),
#  47: array([['диван'],
#         ['токарный'],
#         ['стиральный'],
#         ['кресло']], dtype=object),
#  48: array([['час'],
#         ['мина'],
#         ['минута']], dtype=object),
#  49: array([['прессование'],
#         ['огурец'],
#         ['капуста'],
#         ['виноград'],
#         ['свиной'],
#         ['плодово-ягодный'],
#         ['шрот'],
#         ['томат'],
#         ['мандарин'],
#         ['фуражный'],
#         ['графитированный'],
#         ['обезводить']], dtype=object),
#  52: array([['освежать'],
#         ['классический'],
#         ['виски'],
#         ['био']], dtype=object),
#  54: array([['эч'],
#         ['эы'],
#         ['эш']], dtype=object),
#  55: array([['колпак'],
#         ['рассеиватель'],
#         ['снятой']], dtype=object),
#  56: array([['администрация'],
#         ['департамент'],
#         ['мэрия']], dtype=object),
#  57: array([['сборный'],
#         ['силикатный'],
#         ['шпала'],
#         ['клееный'],
#         ['мелочь']], dtype=object),
#  58: array([['швейный'],
#         ['мороженный'],
#         ['трикотажный'],
#         ['обувной'],
#         ['мучной']], dtype=object),
#  59: array([['экспертиза'],
#         ['строительно-технический'],
#         ['товароведческий'],
#         ['автотехнический'],
#         ['автотовароведческий'],
#         ['судебно-технический'],
#         ['судебно-бухгалтерский']], dtype=object),
#  60: array([['рубка'],
#         ['делянка'],
#         ['выд'],
#         ['белореченский'],
#         ['автомагистраль'],
#         ['окраина'],
#         ['задонский']], dtype=object),
#  61: array([['крепость'],
#         ['слабоалкогольный'],
#         ['алк'],
#         ['ликероводочный'],
#         ['газировать'],
#         ['шампанское'],
#         ['винный'],
#         ['портвейн']], dtype=object),
#  62: array([['ликвидация'],
#         ['ликвидационный'],
#         ['ликвидировать'],
#         ['промежуточный'],
#         ['ликвидатор'],
#         ['ремонтно-реставрационный'],
#         ['инженерно-геодезический'],
#         ['строительно'],
#         ['демонтажный']], dtype=object),
#  63: array([['школа'],
#         ['мдоу'],
#         ['коррекционный'],
#         ['школа-интернат'],
#         ['сказка'],
#         ['моу'],
#         ['мбдоу'],
#         ['сош'],
#         ['интернат'],
#         ['гимназия'],
#         ['моб'],
#         ['углубленный'],
#         ['мкдоу'],
#         ['мкоу']], dtype=object),
#  64: array([['аз'],
#         ['зем'],
#         ['зд-0']], dtype=object),
#  66: array([['бездоказательный'],
#         ['голословный'],
#         ['подкрепить'],
#         ['надуманный']], dtype=object),
#  68: array([['шлиц'],
#         ['самореза']], dtype=object),
#  70: array([['девятьсот'],
#         ['восемьсот'],
#         ['пятьсот'],
#         ['семьсот'],
#         ['девяносто']], dtype=object),
#  71: array([['дп'],
#         ['с-0/0'],
#         ['с-0-0'],
#         ['р-0-0'],
#         ['р-0/0'],
#         ['ирк-0-0'],
#         ['юо-0'],
#         ['л-0/0']], dtype=object),
#  72: array([['далее'],
#         ['научно-производственный'],
#         ['далее–'],
#         ['далее-истец'],
#         ['ремонтно-эксплуатационный'],
#         ['тексту-'],
#         ['холдинговый'],
#         ['производственно-коммерческий']], dtype=object),
#  73: array([['охлаждение'],
#         ['смазка'],
#         ['гидроагрегат']], dtype=object),
#  75: array([['закупаться'],
#         ['привозить'],
#         ['электрик'],
#         ['известняковый'],
#         ['потом'],
#         ['металлоизделие'],
#         ['бригадир'],
#         ['приезжать'],
#         ['маляр']], dtype=object),
#  76: array([['отказать'],
#         ['отклоняться'],
#         ['отклонить'],
#         ['отказывать'],
#         ['согласный'],
#         ['отклонять'],
#         ['соглашаться']], dtype=object),
#  77: array([['переувлажнение'],
#         ['вымерзание'],
#         ['агрометеорологический']], dtype=object),
#  79: array([['порыв'],
#         ['затопить'],
#         ['размораживание']], dtype=object),
#  81: array([['выходной'],
#         ['праздничный'],
#         ['пятница'],
#         ['воскресение'],
#         ['понедельник']], dtype=object),
#  82: array([['агрофирма'],
#         ['надежда'],
#         ['оно']], dtype=object),
#  85: array([['дом'],
#         ['жилой'],
#         ['многоквартирный'],
#         ['мкд']], dtype=object),
#  87: array([['доля'],
#         ['уставный'],
#         ['капитал'],
#         ['капиталь'],
#         ['уставной'],
#         ['складочный']], dtype=object),
#  88: array([['га'],
#         ['пашня'],
#         ['гектар'],
#         ['сенокос'],
#         ['пастбище']], dtype=object),
#  92: array([['пгс'],
#         ['майский']], dtype=object),
#  93: array([['эц'],
#         ['эхо'],
#         ['эу']], dtype=object),
#  94: array([['лейтенант'],
#         ['госинспектор'],
#         ['оперуполномоченный'],
#         ['майор'],
#         ['докладной'],
#         ['дознаватель'],
#         ['врио'],
#         ['инспекторский']], dtype=object),
#  95: array([['наряд-заказ'],
#         ['зн'],
#         ['расходно-кассовый'],
#         ['ремонт-калькуляция'],
#         ['js']], dtype=object),
#  98: array([['зажим'],
#         ['кожух'],
#         ['предохранитель']], dtype=object),
#  99: array([['рассмотреть'],
#         ['исследовать'],
#         ['оценить'],
#         ['изучить'],
#         ['совокупность'],
#         ['заслушать'],
#         ['выслушать'],
#         ['проанализировать'],
#         ['обсудить'],
#         ['заслушав'],
#         ['изучив']], dtype=object),
#  100: array([['сливной'],
#         ['вентиль']], dtype=object),
#  101: array([['м'],
#         ['площадь'],
#         ['кв'],
#         ['метр'],
#         ['квадратный']], dtype=object),
#  102: array([['груженый'],
#         ['авианакладная'],
#         ['баржа'],
#         ['товарно-транспортные'],
#         ['грузоотправителем'],
#         ['ra-0']], dtype=object),
#  103: array([['административный'],
#         ['правонарушение'],
#         ['адми\xadнистративный'],
#         ['администра\xadтивный'],
#         ['правонаруше\xadние'],
#         ['административ\xadный']], dtype=object),
#  104: array([['коммуникационный'],
#         ['наполнение'],
#         ['теплопровод']], dtype=object),
#  105: array([['накладная'],
#         ['товарно-транспортный'],
#         ['накладный'],
#         ['торг-0']], dtype=object),
#  107: array([['прием-передача'],
#         ['приема-передача'],
#         ['передаточный'],
#         ['приемка-передача'],
#         ['приема-']], dtype=object),
#  108: array([['талый'],
#         ['фекальный']], dtype=object),
#  109: array([['заказчик'],
#         ['покупатель'],
#         ['поставщик'],
#         ['исполнитель'],
#         ['подрядчик'],
#         ['субподрядчик'],
#         ['генподрядчик'],
#         ['субподряд']], dtype=object),
#  110: array([['энергия'],
#         ['тепловой'],
#         ['вода'],
#         ['электроэнергия'],
#         ['водоснабжение'],
#         ['горячий'],
#         ['теплоснабжение'],
#         ['теплоэнергия'],
#         ['энергоресурсы']], dtype=object),
#  111: array([['эрозия'],
#         ['древесно-кустарниковый'],
#         ['болото'],
#         ['зарастание']], dtype=object),
#  112: array([['грп'],
#         ['газорегуляторный'],
#         ['шрп']], dtype=object),
#  113: array([['катер'],
#         ['снегоход'],
#         ['лодка']], dtype=object),
#  115: array([['радиочастота'],
#         ['радиоэлектронный'],
#         ['телепрограмма'],
#         ['мгц'],
#         ['рэс'],
#         ['adsl'],
#         ['широкополосный'],
#         ['радиостанция'],
#         ['частотный'],
#         ['радиоканал'],
#         ['радиопрограмма'],
#         ['беспроводный'],
#         ['вещатель'],
#         ['безлимитный'],
#         ['клавиша'],
#         ['старт']], dtype=object),
#  117: array([['кго'],
#         ['бункер-накопитель']], dtype=object),
#  119: array([['дпс'],
#         ['командир'],
#         ['батальон'],
#         ['рота']], dtype=object),
#  120: array([['маковый'],
#         ['начинка'],
#         ['рулет']], dtype=object),
#  128: array([['литер'],
#         ['инвентарный'],
#         ['лит'],
#         ['литера'],
#         ['инв'],
#         ['этажность']], dtype=object),
#  129: array([['перестрахование'],
#         ['премирование'],
#         ['перестраховщик'],
#         ['портфель'],
#         ['факультативный'],
#         ['перестраховочный'],
#         ['поощрение'],
#         ['поощрительный'],
#         ['перестрахователь']], dtype=object),
#  131: array([['фотография'],
#         ['фотоматериал'],
#         ['фототаблица'],
#         ['фотоснимок'],
#         ['фото'],
#         ['отображение'],
#         ['отобразить'],
#         ['снимок'],
#         ['фотофиксация'],
#         ['прослушивание']], dtype=object),
#  132: array([['счет-фактура'],
#         ['фактура'],
#         ['счет-'],
#         ['счета-']], dtype=object),
#  134: array([['подпись'],
#         ['печать'],
#         ['учинить'],
#         ['оттиском'],
#         ['оттиска']], dtype=object),
#  137: array([['adidas'],
#         ['адидас'],
#         ['didas']], dtype=object),
#  138: array([['архангельск'],
#         ['сыктывкар'],
#         ['ифнс']], dtype=object),
#  139: array([['стоматология'],
#         ['хирургический'],
#         ['терапевтический'],
#         ['косметология']], dtype=object),
#  141: array([['журнал-ордер'],
#         ['сальдовый']], dtype=object),
#  143: array([['лизинг'],
#         ['лизингополучатель'],
#         ['лизингодатель']], dtype=object),
#  144: array([['досудебный'],
#         ['претензионный'],
#         ['преддоговорный'],
#         ['неурегулированный'],
#         ['претензионного'],
#         ['неурегулирование']], dtype=object),
#  151: array([['закон'],
#         ['федеральный'],
#         ['фз']], dtype=object),
#  152: array([['высокотехнологичный'],
#         ['дезинфекционный'],
#         ['наркологический'],
#         ['консультативный']], dtype=object),
#  153: array([['трехкомнатный'],
#         ['двухкомнатный'],
#         ['однокомнатный']], dtype=object),
#  154: array([['локально-сметный'],
#         ['поручаемых']], dtype=object),
#  158: array([['сервер'],
#         ['программно-аппаратный'],
#         ['windows'],
#         ['web'],
#         ['prime'],
#         ['power']], dtype=object),
#  159: array([['арендатор'],
#         ['субарендатор'],
#         ['сублизингодатель'],
#         ['субарендодатель']], dtype=object),
#  162: array([['помещение'],
#         ['здание'],
#         ['нежилой'],
#         ['сооружение'],
#         ['строение']], dtype=object),
#  164: array([['снег'],
#         ['наледь'],
#         ['лед'],
#         ['сосулька']], dtype=object),
#  165: array([['пр-во'],
#         ['снукер'],
#         ['кий']], dtype=object),
#  166: array([['кассовый'],
#         ['ордер'],
#         ['чек'],
#         ['приходный']], dtype=object),
#  168: array([['соревнование'],
#         ['концерт'],
#         ['фестиваль']], dtype=object),
#  170: array([['отправляться'],
#         ['бандероль']], dtype=object),
#  173: array([['пю'],
#         ['рш']], dtype=object),
#  175: array([['°'],
#         ['кгс']], dtype=object),
#  177: array([['двенадцатый'],
#         ['четырнадцатый'],
#         ['тринадцатый']], dtype=object),
#  178: array([['есн'],
#         ['тфомс'],
#         ['фб'],
#         ['фсс']], dtype=object),
#  180: array([['катастрофа'],
#         ['жертва'],
#         ['репрессия']], dtype=object),
#  182: array([['лпд'],
#         ['спд'],
#         ['спдр'],
#         ['спдф']], dtype=object),
#  190: array([['незаключенность'],
#         ['несогласованность'],
#         ['незаключенности']], dtype=object),
#  191: array([['поддержать'],
#         ['возражать'],
#         ['настаивать']], dtype=object),
#  193: array([['ссудодатель'],
#         ['дар'],
#         ['одарять'],
#         ['даритель']], dtype=object),
#  195: array([['документация'],
#         ['проектный'],
#         ['проектно-сметный']], dtype=object),
#  197: array([['обоснованность'],
#         ['законность'],
#         ['правомерность'],
#         ['необоснованность'],
#         ['незаконность'],
#         ['неправомерность']], dtype=object),
#  198: array([['уничтожаться'],
#         ['транспортироваться'],
#         ['воспламеняющийся'],
#         ['перерабатываться']], dtype=object),
#  202: array([['море'],
#         ['шельф'],
#         ['континентальный']], dtype=object),
#  203: array([['перевозка'],
#         ['груз'],
#         ['перевозчик'],
#         ['грузополучатель'],
#         ['грузоотправитель']], dtype=object),
#  204: array([['дтп'],
#         ['происшествие'],
#         ['дорожно-транспортный']], dtype=object),
#  207: array([['влиять'],
#         ['повлиять'],
#         ['негативно'],
#         ['отразиться'],
#         ['сказаться']], dtype=object),
#  208: array([['вменяемый'],
#         ['вменять'],
#         ['инкриминировать'],
#         ['раскаяние'],
#         ['проступок']], dtype=object),
#  209: array([['безопасность'],
#         ['пожарный'],
#         ['санитарно-'],
#         ['пропаганда']], dtype=object),
#  210: array([['дезинфекция'],
#         ['дератизация'],
#         ['дезинсекция']], dtype=object),
#  211: array([['лестничный'],
#         ['лестница'],
#         ['клетка'],
#         ['марш']], dtype=object),
#  212: array([['знакомый'],
#         ['помнить'],
#         ['слышать']], dtype=object),
#  214: array([['послерейсовый'],
#         ['медосмотр'],
#         ['водитель-предприниматель'],
#         ['минавтотранс'],
#         ['рд-0-рсфср-0-0-0-0']], dtype=object),
#  216: array([['денатурат'],
#         ['нефасованный']], dtype=object),
#  217: array([['аукцион'],
#         ['торг'],
#         ['конкурс'],
#         ['победитель']], dtype=object),
#  220: array([['viii'],
#         ['vii'],
#         ['xi'],
#         ['ix'],
#         ['vi'],
#         ['xiii'],
#         ['xii']], dtype=object),
#  221: array([['корова'],
#         ['поголовье'],
#         ['стадо']], dtype=object),
#  225: array([['земельный'],
#         ['участок'],
#         ['кадастровый'],
#         ['земля'],
#         ['зк'],
#         ['испрашивать']], dtype=object),
#  228: array([['обоснованный'],
#         ['правомерно'],
#         ['правомерный'],
#         ['обоснованно'],
#         ['обосновать'],
#         ['необоснованно'],
#         ['неправомерно']], dtype=object),
#  229: array([['провести'],
#         ['проводиться']], dtype=object),
#  231: array([['областной'],
#         ['финансировать'],
#         ['краевой'],
#         ['республиканский']], dtype=object),
#  232: array([['купля-продажа'],
#         ['купля'],
#         ['купли-']], dtype=object),
#  240: array([['контора'],
#         ['букмекерский'],
#         ['тотализатор']], dtype=object),
#  244: array([['ошибка'],
#         ['исправление'],
#         ['опечатка'],
#         ['описка']], dtype=object),
#  247: array([['утвердить'],
#         ['утверждение']], dtype=object),
#  249: array([['предоставление'],
#         ['предоставить'],
#         ['предоставлять'],
#         ['предоставляться']], dtype=object),
#  251: array([['коэффициент'],
#         ['повышать'],
#         ['индексация'],
#         ['понижать'],
#         ['поправочный']], dtype=object),
#  254: array([['пленум'],
#         ['вы'],
#         ['вас']], dtype=object),
#  258: array([['негаторный'],
#         ['виндикация']], dtype=object),
#  259: array([['акция'],
#         ['номинальный'],
#         ['именной'],
#         ['обыкновенный'],
#         ['бездокументарный'],
#         ['привилегированный']], dtype=object),
#  260: array([['прибор'],
#         ['счетчик']], dtype=object),
#  261: array([['металл'],
#         ['черный'],
#         ['лом'],
#         ['цветной']], dtype=object),
#  262: array([['аванс'],
#         ['неотработанный'],
#         ['неосвоенный']], dtype=object),
#  266: array([['i'],
#         ['ii'],
#         ['iii'],
#         ['iv']], dtype=object),
#  268: array([['допрос'],
#         ['допросить'],
#         ['опрос'],
#         ['опросить']], dtype=object),
#  270: array([['собрание'],
#         ['акционер'],
#         ['внеочередной']], dtype=object),
#  271: array([['кг'],
#         ['вес'],
#         ['нетто'],
#         ['брутто']], dtype=object),
#  277: array([['опубликовать'],
#         ['газета'],
#         ['публикация']], dtype=object),
#  279: array([['заем'],
#         ['кредитный'],
#         ['кредит'],
#         ['заемщик'],
#         ['заимодавец'],
#         ['кредитование'],
#         ['транш'],
#         ['овердрафт'],
#         ['микрозаем'],
#         ['возобновлять']], dtype=object),
#  280: array([['выдать'],
#         ['выдача'],
#         ['выдавать'],
#         ['выдаваться']], dtype=object),
#  281: array([['спецтехника'],
#         ['автокран']], dtype=object),
#  283: array([['обязать'],
#         ['обязание'],
#         ['обязании'],
#         ['обязаний']], dtype=object),
#  285: array([['рсв-0'],
#         ['адв-0-0'],
#         ['сзв-0-0'],
#         ['пфр'],
#         ['адв-0']], dtype=object),
#  286: array([['аппаратура'],
#         ['глонасс'],
#         ['навигация'],
#         ['спутниковый'],
#         ['gps']], dtype=object),
#  291: array([['наследование'],
#         ['выморочный']], dtype=object),
#  293: array([['износ'],
#         ['узел'],
#         ['деталь'],
#         ['агрегат'],
#         ['заменять']], dtype=object),
#  300: array([['культурный'],
#         ['наследие'],
#         ['памятник'],
#         ['история']], dtype=object),
#  305: array([['дочерний'],
#         ['зависимый'],
#         ['преобладать'],
#         ['преобладающих']], dtype=object),
#  309: array([['пролонгация'],
#         ['пролонгировать'],
#         ['пролонгироваться']], dtype=object),
#  310: array([['водный'],
#         ['биоресурсы'],
#         ['водопользователь']], dtype=object),
#  312: array([['перепланировка'],
#         ['переустройство'],
#         ['переоборудование']], dtype=object),
#  313: array([['гтд'],
#         ['дт'],
#         ['задекларировать']], dtype=object),
#  315: array([['залог'],
#         ['ипотека'],
#         ['залогодержатель'],
#         ['залогодатель']], dtype=object),
#  317: array([['более'],
#         ['чем'],
#         ['менее']], dtype=object),
#  320: array([['относиться'],
#         ['отнесение'],
#         ['отнести'],
#         ['относить']], dtype=object),
#  322: array([['продаваться'],
#         ['ярмарка'],
#         ['выставка'],
#         ['демонстрироваться']], dtype=object),
#  326: array([['ценный'],
#         ['бумага'],
#         ['эмитент'],
#         ['эмиссионный'],
#         ['эмиссия']], dtype=object),
#  337: array([['рыболовство'],
#         ['рыбопромысловый'],
#         ['рыбоводство']], dtype=object),
#  346: array([['средний'],
#         ['малый'],
#         ['предпринимательство']], dtype=object),
#  352: array([['полно'],
#         ['всесторонне'],
#         ['объективно']], dtype=object)}
